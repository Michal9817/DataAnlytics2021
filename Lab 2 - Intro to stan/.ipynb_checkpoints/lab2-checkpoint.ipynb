# %%
from cmdstanpy import CmdStanModel
import pandas as pd
import arviz as az 
import numpy as np
import matplotlib.pyplot as plt
import scipy.stats as stats

# %% [markdown]
# ## Excercise 1 -  Generated Quantities Block

# %%
F=len("Michał")
L=len("Druciak")

# %%
gen_quant = CmdStanModel(stan_file='code_1.stan')
# Out:
# INFO:cmdstanpy:compiling stan program, exe file: C:/Users/Studia/DOCUME~1/GitHub/PUBLIC~1/DATAAN~1/LAB2-I~1/code_1.exe
# INFO:cmdstanpy:compiler options: stanc_options=None, cpp_options=None
# INFO:cmdstanpy:compiled model file: C:/Users/Studia/DOCUME~1/GitHub/PUBLIC~1/DATAAN~1/LAB2-I~1/code_1.exe

# %%
samples = gen_quant.sample(data={'M':F}, 
                            fixed_param=True, 
                            iter_sampling=1000, 
                            iter_warmup=0, 
                            chains = 1)
# Out:
# INFO:cmdstanpy:start chain 1
# INFO:cmdstanpy:finish chain 1

# %%
idata = az.from_cmdstanpy(samples)

df = idata.to_dataframe()

df.columns = [item if isinstance(item, str) else item[1] for item in df.columns]

# %%
df.loc[:,'lambda':'y_sim[5]'].plot.hist(subplots=True)
# Out:
# array([<AxesSubplot:ylabel='Frequency'>, <AxesSubplot:ylabel='Frequency'>,
#        <AxesSubplot:ylabel='Frequency'>, <AxesSubplot:ylabel='Frequency'>,
#        <AxesSubplot:ylabel='Frequency'>, <AxesSubplot:ylabel='Frequency'>,
#        <AxesSubplot:ylabel='Frequency'>], dtype=object)

# %% [markdown]
# ## Excercise 2 - Constraints on the data

# %%
bern1 = CmdStanModel(stan_file='code_2.stan')
samp_bern1 = bern1.sample(data={'N':2, 'y':[0,2]})
# Out:
# INFO:cmdstanpy:compiling stan program, exe file: C:/Users/Studia/DOCUME~1/GitHub/PUBLIC~1/DATAAN~1/LAB2-I~1/code_2.exe
# INFO:cmdstanpy:compiler options: stanc_options=None, cpp_options=None
# INFO:cmdstanpy:compiled model file: C:/Users/Studia/DOCUME~1/GitHub/PUBLIC~1/DATAAN~1/LAB2-I~1/code_2.exe
# INFO:cmdstanpy:start chain 1
# INFO:cmdstanpy:start chain 2
# INFO:cmdstanpy:finish chain 2
# INFO:cmdstanpy:start chain 3
# INFO:cmdstanpy:finish chain 1
# INFO:cmdstanpy:start chain 4
# INFO:cmdstanpy:finish chain 3
# INFO:cmdstanpy:finish chain 4
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-15-ec4689e33596> in <module>
#       1 bern1 = CmdStanModel(stan_file='code_2.stan')
# ----> 2 samp_bern1 = bern1.sample(data={'N':2, 'y':[0,2]})
#
# ~\anaconda3\lib\site-packages\cmdstanpy\model.py in sample(self, data, chains, parallel_chains, threads_per_chain, seed, chain_ids, inits, iter_warmup, iter_sampling, save_warmup, thin, max_treedepth, metric, step_size, adapt_engaged, adapt_delta, adapt_init_phase, adapt_metric_window, adapt_step_size, fixed_param, output_dir, sig_figs, save_diagnostics, show_progress, validate_csv)
#     787             if not runset._check_retcodes():
#     788                 msg = 'Error during sampling.\n{}'.format(runset.get_err_msgs())
# --> 789                 raise RuntimeError(msg)
#     790
#     791             mcmc = CmdStanMCMC(runset, validate_csv, logger=self._logger)
#
# RuntimeError: Error during sampling.
# RunSet: chains=4
#  cmd:
# 	['C:/Users/Studia/DOCUME~1/GitHub/PUBLIC~1/DATAAN~1/LAB2-I~1/code_2.exe', 'id=1', 'random', 'seed=87312', 'data', 'file=C:\\Users\\Studia\\AppData\\Local\\Temp\\tmph4ysj6l4\\3ppjmi5h.json', 'output', 'file=C:\\Users\\Studia\\AppData\\Local\\Temp\\tmph4ysj6l4\\code_2-202103241207-1-ck8q29bu.csv', 'method=sample', 'algorithm=hmc', 'adapt', 'engaged=1']
#  retcodes=[70, 70, 70, 70]
#  csv_files:
# 	C:\Users\Studia\AppData\Local\Temp\tmph4ysj6l4\code_2-202103241207-1-ck8q29bu.csv
# 	C:\Users\Studia\AppData\Local\Temp\tmph4ysj6l4\code_2-202103241207-2-pjm_dm0x.csv
# 	C:\Users\Studia\AppData\Local\Temp\tmph4ysj6l4\code_2-202103241207-3-y__n8t1z.csv
# 	C:\Users\Studia\AppData\Local\Temp\tmph4ysj6l4\code_2-202103241207-4-oeaeja10.csv
#  console_msgs:
# 	C:\Users\Studia\AppData\Local\Temp\tmph4ysj6l4\code_2-202103241207-1-ck8q29bu-stdout.txt
# 	C:\Users\Studia\AppData\Local\Temp\tmph4ysj6l4\code_2-202103241207-2-pjm_dm0x-stdout.txt
# 	C:\Users\Studia\AppData\Local\Temp\tmph4ysj6l4\code_2-202103241207-3-y__n8t1z-stdout.txt
# 	C:\Users\Studia\AppData\Local\Temp\tmph4ysj6l4\code_2-202103241207-4-oeaeja10-stdout.txt
# chain_id 1:
# 	Exception: bernoulli_lpmf: n[2] is 2, but must be in the interval [0, 1] (in 'C:/Users/Studia/DOCUME~1/GitHub/PUBLIC~1/DATAAN~1/LAB2-I~1/code_2.stan', line 12, column 4 to column 25)
# 	Exception: bernoulli_lpmf: n[2] is 2, but must be in the interval [0, 1] (in 'C:/Users/Studia/DOCUME~1/GitHub/PUBLIC~1/DATAAN~1/LAB2-I~1/code_2.stan', line 12, column 4 to column 25)
# 	Exception: bernoulli_lpmf: n[2] is 2, but must be in the interval [0, 1] (in 'C:/Users/Studia/DOCUME~1/GitHub/PUBLIC~1/DATAAN~1/LAB2-I~1/code_2.stan', line 12, column 4 to column 25)
# 	Exception: bernoulli_lpmf: n[2] is 2, but must be in the interval [0, 1] (in 'C:/Users/Studia/DOCUME~1/GitHub/PUBLIC~1/DATAAN~1/LAB2-I~1/code_2.stan', line 12, column 4 to column 25)
# 	Exception: bernoulli_lpmf: n[2] is 2, but must be in the interval [0, 1] (in 'C:/Users/Studia/DOCUME~1/GitHub/PUBLIC~1/DATAAN~1/LAB2-I~1/code_2.stan', line 12, column 4 to column 25)
# 	Exception: bernoulli_lpmf: n[2] is 2, but must be in the interval [0, 1] (in 'C:/Users/Studia/DOCUME~1/GitHub/PUBLIC~1/DATAAN~1/LAB2-I~1/code_2.stan', line 12, column 4 to column 25)
# 	Exception: bernoulli_lpmf: n[2] is 2, but must be in the interval [0, 1] (in 'C:/Users/Studia/DOCUME~1/GitHub/PUBLIC~1/DATAAN~1/LAB2-I~1/code_2.stan', line 12, column 4 to column 25)
# 	Exception: bernoulli_lpmf: n[2] is 2, but must be in the interval [0, 1] (in 'C:/Users/Studia/DOCUME~1/GitHub/PUBLIC~1/DATAAN~1/LAB2-I~1/code_2.stan', line 12, column 4 to column 25)
# 	Exception: bernoulli_lpmf: n[2] is 2, but must be in the interval [0, 1] (in 'C:/Users/Studia/DOCUME~1/GitHub/PUBLIC~1/DATAAN~1/LAB2-I~1/code_2.stan', line 12, column 4 to column 25)
# 	Exception: bernoulli_lpmf: n[2] is 2, but must be in the interval [0, 1] (in 'C:/Users/Studia/DOCUME~1/GitHub/PUBLIC~1/DATAAN~1/LAB2-I~1/code_2.stan', line 12, column 4 to column 25)
# 	Exception: bernoulli_lpmf: n[2] is 2, but must be in the interval [0, 1] (in 'C:/Users/Studia/DOCUME~1/GitHub/PUBLIC~1/DATAAN~1/LAB2-I~1/code_2.stan', line 12, column 4 to column 25)
# 	Exception: bernoulli_lpmf: n[2] is 2, but must be in the interval [0, 1] (in 'C:/Users/Studia/DOCUME~1/GitHub/PUBLIC~1/DATAAN~1/LAB2-I~1/code_2.stan', line 12, column 4 to column 25)
# 	Exception: bernoulli_lpmf: n[2] is 2, but must be in the interval [0, 1] (in 'C:/Users/Studia/DOCUME~1/GitHub/PUBLIC~1/DATAAN~1/LAB2-I~1/code_2.stan', line 12, column 4 to column 25)
# 	Exception: bernoulli_lpmf: n[2] is 2, but must be in the interval [0, 1] (in 'C:/Users/Studia/DOCUME~1/GitHub/PUBLIC~1/DATAAN~1/LAB2-I~1/code_2.stan', line 12, column 4 to column 25)
# 	Exception: bernoulli_lpmf: n[2] is 2, but must be in the interval [0, 1] (in 'C:/Users/Studia/DOCUME~1/GitHub/PUBLIC~1/DATAAN~1/LAB2-I~1/code_2.stan', line 12, column 4 to column 25)
# 	Exception: bernoulli_lpmf: n[2] is 2, but must be in the interval [0, 1] (in 'C:/Users/Studia/DOCUME~1/GitHub/PUBLIC~1/DATAAN~1/LAB2-I~1/code_2.stan', line 12, column 4 to column 25)
# 	Exception: bernoulli_lpmf: n[2] is 2, but must be in the interval [0, 1] (in 'C:/Users/Studia/DOCUME~1/GitHub/PUBLIC~1/DATAAN~1/LAB2-I~1/code_2.stan', line 12, column 4 to column 25)
# 	Exception: bernoulli_lpmf: n[2] is 2, but must be in the interval [0, 1] (in 'C:/Users/Studia/DOCUME~1/GitHub/PUBLIC~1/DATAAN~1/LAB2-I~1/code_2.stan', line 12, column 4 to column 25)
# 	Exception: bernoulli_lpmf: n[2] is 2, but must be in the interval [0, 1] (in 'C:/Users/Studia/DOCUME~1/GitHub/PUBLIC~1/DATAAN~1/LAB2-I~1/code_2.stan', line 12, column 4 to column 25)
# 	Exception: bernoulli_lpmf: n[2] is 2, but must be in the interval [0, 1] (in 'C:/Users/Studia/DOCUME~1/GitHub/PUBLIC~1/DATAAN~1/LAB2-I~1/code_2.stan', line 12, column 4 to column 25)
# 	Exception: bernoulli_lpmf: n[2] is 2, but must be in the interval [0, 1] (in 'C:/Users/Studia/DOCUME~1/GitHub/PUBLIC~1/DATAAN~1/LAB2-I~1/code_2.stan', line 12, column 4 to column 25)
# 	Exception: bernoulli_lpmf: n[2] is 2, but must be in the interval [0, 1] (in 'C:/Users/Studia/DOCUME~1/GitHub/PUBLIC~1/DATAAN~1/LAB2-I~1/code_2.stan', line 12, column 4 to column 25)
# 	Exception: bernoulli_lpmf: n[2] is 2, but must be in the interval [0, 1] (in 'C:/Users/Studia/DOCUME~1/GitHub/PUBLIC~1/DATAAN~1/LAB2-I~1/code_2.stan', line 12, column 4 to column 25)
# 	Exception: bernoulli_lpmf: n[2] is 2, but must be in the interval [0, 1] (in 'C:/Users/Studia/DOCUME~1/GitHub/PUBLIC~1/DATAAN~1/LAB2-I~1/code_2.stan', line 12, column 4 to column 25)
# 	Exception: bernoulli_lpmf: n[2] is 2, but must be in the interval [0, 1] (in 'C:/Users/Studia/DOCUME~1/GitHub/PUBLIC~1/DATAAN~1/LAB2-I~1/code_2.stan', line 12, column 4 to column 25)
# 	Exception: bernoulli_lpmf: n[2] is 2, but must be in the interval [0, 1] (in 'C:/Users/Studia/DOCUME~1/GitHub/PUBLIC~1/DATAAN~1/LAB2-I~1/code_2.stan', line 12, column 4 to column 25)
# 	Exception: bernoulli_lpmf: n[2] is 2, but must be in the interval [0, 1] (in 'C:/Users/Studia/DOCUME~1/GitHub/PUBLIC~1/DATAAN~1/LAB2-I~1/code_2.stan', line 12, column 4 to column 25)
# 	Exception: bernoulli_lpmf: n[2] is 2, but must be in the interval [0, 1] (in 'C:/Users/Studia/DOCUME~1/GitHub/PUBLIC~1/DATAAN~1/LAB2-I~1/code_2.stan', line 12, column 4 to column 25)
# 	Exception: bernoulli_lpmf: n[2] is 2, but must be in the interval [0, 1] (in 'C:/Users/Studia/DOCUME~1/GitHub/PUBLIC~1/DATAAN~1/LAB2-I~1/code_2.stan', line 12, column 4 to column 25)
# 	Exception: bernoulli_lpmf: n[2] is 2, but must be in the interval [0, 1] (in 'C:/Users/Studia/DOCUME~1/GitHub/PUBLIC~1/DATAAN~1/LAB2-I~1/code_2.stan', line 12, column 4 to column 25)
# 	Exception: bernoulli_lpmf: n[2] is 2, but must be in the interval [0, 1] (in 'C:/Users/Studia/DOCUME~1/GitHub/PUBLIC~1/DATAAN~1/LAB2-I~1/code_2.stan', line 12, column 4 to column 25)
# 	Exception: bernoulli_lpmf: n[2] is 2, but must be in the interval [0, 1] (in 'C:/Users/Studia/DOCUME~1/GitHub/PUBLIC~1/DATAAN~1/LAB2-I~1/code_2.stan', line 12, column 4 to column 25)
# 	Exception: bernoulli_lpmf: n[2] is 2, but must be in the interval [0, 1] (in 'C:/Users/Studia/DOCUME~1/GitHub/PUBLIC~1/DATAAN~1/LAB2-I~1/code_2.stan', line 12, column 4 to column 25)
# 	Exception: bernoulli_lpmf: n[2] is 2, but must be in the interval [0, 1] (in 'C:/Users/Studia/DOCUME~1/GitHub/PUBLIC~1/DATAAN~1/LAB2-I~1/code_2.stan', line 12, column 4 to column 25)
# 	Exception: bernoulli_lpmf: n[2] is 2, but must be in the interval [0, 1] (in 'C:/Users/Studia/DOCUME~1/GitHub/PUBLIC~1/DATAAN~1/LAB2-I~1/code_2.stan', line 12, column 4 to column 25)
# 	Exception: bernoulli_lpmf: n[2] is 2, but must be in the interval [0, 1] (in 'C:/Users/Studia/DOCUME~1/GitHub/PUBLIC~1/DATAAN~1/LAB2-I~1/code_2.stan', line 12, column 4 to column 25)
# 	Exception: bernoulli_lpmf: n[2] is 2, but must be in the interval [0, 1] (in 'C:/Users/Studia/DOCUME~1/GitHub/PUBLIC~1/DATAAN~1/LAB2-I~1/code_2.stan', line 12, column 4 to column 25)
# 	Exception: bernoulli_lpmf: n[2] is 2, but must be in the interval [0, 1] (in 'C:/Users/Studia/DOCUME~1/GitHub/PUBLIC~1/DATAAN~1/LAB2-I~1/code_2.stan', line 12, column 4 to column 25)
# 	Exception: bernoulli_lpmf: n[2] is 2, but must be in the interval [0, 1] (in 'C:/Users/Studia/DOCUME~1/GitHub/PUBLIC~1/DATAAN~1/LAB2-I~1/code_2.stan', line 12, column 4 to column 25)
# 	Exception: bernoulli_lpmf: n[2] is 2, but must be in the interval [0, 1] (in 'C:/Users/Studia/DOCUME~1/GitHub/PUBLIC~1/DATAAN~1/LAB2-I~1/code_2.stan', line 12, column 4 to column 25)
# 	Exception: bernoulli_lpmf: n[2] is 2, but must be in the interval [0, 1] (in 'C:/Users/Studia/DOCUME~1/GitHub/PUBLIC~1/DATAAN~1/LAB2-I~1/code_2.stan', line 12, column 4 to column 25)
# 	Exception: bernoulli_lpmf: n[2] is 2, but must be in the interval [0, 1] (in 'C:/Users/Studia/DOCUME~1/GitHub/PUBLIC~1/DATAAN~1/LAB2-I~1/code_2.stan', line 12, column 4 to column 25)
# 	Exception: bernoulli_lpmf: n[2] is 2, but must be in the interval [0, 1] (in 'C:/Users/Studia/DOCUME~1/GitHub/PUBLIC~1/DATAAN~1/LAB2-I~1/code_2.stan', line 12, column 4 to column 25)
# 	Exception: bernoulli_lpmf: n[2] is 2, but must be in the interval [0, 1] (in 'C:/Users/Studia/DOCUME~1/GitHub/PUBLIC~1/DATAAN~1/LAB2-I~1/code_2.stan', line 12, column 4 to column 25)
# 	Exception: bernoulli_lpmf: n[2] is 2, but must be in the interval [0, 1] (in 'C:/Users/Studia/DOCUME~1/GitHub/PUBLIC~1/DATAAN~1/LAB2-I~1/code_2.stan', line 12, column 4 to column 25)
# 	Exception: bernoulli_lpmf: n[2] is 2, but must be in the interval [0, 1] (in 'C:/Users/Studia/DOCUME~1/GitHub/PUBLIC~1/DATAAN~1/LAB2-I~1/code_2.stan', line 12, column 4 to column 25)
# 	Exception: bernoulli_lpmf: n[2] is 2, but must be in the interval [0, 1] (in 'C:/Users/Studia/DOCUME~1/GitHub/PUBLIC~1/DATAAN~1/LAB2-I~1/code_2.stan', line 12, column 4 to column 25)
# 	Exception: bernoulli_lpmf: n[2] is 2, but must be in the interval [0, 1] (in 'C:/Users/Studia/DOCUME~1/GitHub/PUBLIC~1/DATAAN~1/LAB2-I~1/code_2.stan', line 12, column 4 to column 25)
# 	Exception: bernoulli_lpmf: n[2] is 2, but must be in the interval [0, 1] (in 'C:/Users/Studia/DOCUME~1/GitHub/PUBLIC~1/DATAAN~1/LAB2-I~1/code_2.stan', line 12, column 4 to column 25)
# 	Exception: bernoulli_lpmf: n[2] is 2, but must be in the interval [0, 1] (in 'C:/Users/Studia/DOCUME~1/GitHub/PUBLIC~1/DATAAN~1/LAB2-I~1/code_2.stan', line 12, column 4 to column 25)
# 	Exception: bernoulli_lpmf: n[2] is 2, but must be in the interval [0, 1] (in 'C:/Users/Studia/DOCUME~1/GitHub/PUBLIC~1/DATAAN~1/LAB2-I~1/code_2.stan', line 12, column 4 to column 25)
# 	Exception: bernoulli_lpmf: n[2] is 2, but must be in the interval [0, 1] (in 'C:/Users/Studia/DOCUME~1/GitHub/PUBLIC~1/DATAAN~1/LAB2-I~1/code_2.stan', line 12, column 4 to column 25)
# 	Exception: bernoulli_lpmf: n[2] is 2, but must be in the interval [0, 1] (in 'C:/Users/Studia/DOCUME~1/GitHub/PUBLIC~1/DATAAN~1/LAB2-I~1/code_2.stan', line 12, column 4 to column 25)
# 	Exception: bernoulli_lpmf: n[2] is 2, but must be in the interval [0, 1] (in 'C:/Users/Studia/DOCUME~1/GitHub/PUBLIC~1/DATAAN~1/LAB2-I~1/code_2.stan', line 12, column 4 to column 25)
# 	Exception: bernoulli_lpmf: n[2] is 2, but must be in the interval [0, 1] (in 'C:/Users/Studia/DOCUME~1/GitHub/PUBLIC~1/DATAAN~1/LAB2-I~1/code_2.stan', line 12, column 4 to column 25)
# 	Exception: bernoulli_lpmf: n[2] is 2, but must be in the interval [0, 1] (in 'C:/Users/Studia/DOCUME~1/GitHub/PUBLIC~1/DATAAN~1/LAB2-I~1/code_2.stan', line 12, column 4 to column 25)
# 	Exception: bernoulli_lpmf: n[2] is 2, but must be in the interval [0, 1] (in 'C:/Users/Studia/DOCUME~1/GitHub/PUBLIC~1/DATAAN~1/LAB2-I~1/code_2.stan', line 12, column 4 to column 25)
# 	Exception: bernoulli_lpmf: n[2] is 2, but must be in the interval [0, 1] (in 'C:/Users/Studia/DOCUME~1/GitHub/PUBLIC~1/DATAAN~1/LAB2-I~1/code_2.stan', line 12, column 4 to column 25)
# 	Exception: bernoulli_lpmf: n[2] is 2, but must be in the interval [0, 1] (in 'C:/Users/Studia/DOCUME~1/GitHub/PUBLIC~1/DATAAN~1/LAB2-I~1/code_2.stan', line 12, column 4 to column 25)
# 	Exception: bernoulli_lpmf: n[2] is 2, but must be in the interval [0, 1] (in 'C:/Users/Studia/DOCUME~1/GitHub/PUBLIC~1/DATAAN~1/LAB2-I~1/code_2.stan', line 12, column 4 to column 25)
# 	Exception: bernoulli_lpmf: n[2] is 2, but must be in the interval [0, 1] (in 'C:/Users/Studia/DOCUME~1/GitHub/PUBLIC~1/DATAAN~1/LAB2-I~1/code_2.stan', line 12, column 4 to column 25)
# 	Exception: bernoulli_lpmf: n[2] is 2, but must be in the interval [0, 1] (in 'C:/Users/Studia/DOCUME~1/GitHub/PUBLIC~1/DATAAN~1/LAB2-I~1/code_2.stan', line 12, column 4 to column 25)
# 	Exception: bernoulli_lpmf: n[2] is 2, but must be in the interval [0, 1] (in 'C:/Users/Studia/DOCUME~1/GitHub/PUBLIC~1/DATAAN~1/LAB2-I~1/code_2.stan', line 12, column 4 to column 25)
# 	Exception: bernoulli_lpmf: n[2] is 2, but must be in the interval [0, 1] (in 'C:/Users/Studia/DOCUME~1/GitHub/PUBLIC~1/DATAAN~1/LAB2-I~1/code_2.stan', line 12, column 4 to column 25)
# 	Exception: bernoulli_lpmf: n[2] is 2, but must be in the interval [0, 1] (in 'C:/Users/Studia/DOCUME~1/GitHub/PUBLIC~1/DATAAN~1/LAB2-I~1/code_2.stan', line 12, column 4 to column 25)
# 	Exception: bernoulli_lpmf: n[2] is 2, but must be in the interval [0, 1] (in 'C:/Users/Studia/DOCUME~1/GitHub/PUBLIC~1/DATAAN~1/LAB2-I~1/code_2.stan', line 12, column 4 to column 25)
# 	Exception: bernoulli_lpmf: n[2] is 2, but must be in the interval [0, 1] (in 'C:/Users/Studia/DOCUME~1/GitHub/PUBLIC~1/DATAAN~1/LAB2-I~1/code_2.stan', line 12, column 4 to column 25)
# 	Exception: bernoulli_lpmf: n[2] is 2, but must be in the interval [0, 1] (in 'C:/Users/Studia/DOCUME~1/GitHub/PUBLIC~1/DATAAN~1/LAB2-I~1/code_2.stan', line 12, column 4 to column 25)
# 	Exception: bernoulli_lpmf: n[2] is 2, but must be in the interval [0, 1] (in 'C:/Users/Studia/DOCUME~1/GitHub/PUBLIC~1/DATAAN~1/LAB2-I~1/code_2.stan', line 12, column 4 to column 25)
# 	Exception: bernoulli_lpmf: n[2] is 2, but must be in the interval [0, 1] (in 'C:/Users/Studia/DOCUME~1/GitHub/PUBLIC~1/DATAAN~1/LAB2-I~1/code_2.stan', line 12, column 4 to column 25)
# 	Exception: bernoulli_lpmf: n[2] is 2, but must be in the interval [0, 1] (in 'C:/Users/Studia/DOCUME~1/GitHub/PUBLIC~1/DATAAN~1/LAB2-I~1/code_2.stan', line 12, column 4 to column 25)
# 	Exception: bernoulli_lpmf: n[2] is 2, but must be in the interval [0, 1] (in 'C:/Users/Studia/DOCUME~1/GitHub/PUBLIC~1/DATAAN~1/LAB2-I~1/code_2.stan', line 12, column 4 to column 25)
# 	Exception: bernoulli_lpmf: n[2] is 2, but must be in the interval [0, 1] (in 'C:/Users/Studia/DOCUME~1/GitHub/PUBLIC~1/DATAAN~1/LAB2-I~1/code_2.stan', line 12, column 4 to column 25)
# 	Exception: bernoulli_lpmf: n[2] is 2, but must be in the interval [0, 1] (in 'C:/Users/Studia/DOCUME~1/GitHub/PUBLIC~1/DATAAN~1/LAB2-I~1/code_2.stan', line 12, column 4 to column 25)
# 	Exception: bernoulli_lpmf: n[2] is 2, but must be in the interval [0, 1] (in 'C:/Users/Studia/DOCUME~1/GitHub/PUBLIC~1/DATAAN~1/LAB2-I~1/code_2.stan', line 12, column 4 to column 25)
# 	Exception: bernoulli_lpmf: n[2] is 2, but must be in the interval [0, 1] (in 'C:/Users/Studia/DOCUME~1/GitHub/PUBLIC~1/DATAAN~1/LAB2-I~1/code_2.stan', line 12, column 4 to column 25)
# 	Exception: bernoulli_lpmf: n[2] is 2, but must be in the interval [0, 1] (in 'C:/Users/Studia/DOCUME~1/GitHub/PUBLIC~1/DATAAN~1/LAB2-I~1/code_2.stan', line 12, column 4 to column 25)
# 	Exception: bernoulli_lpmf: n[2] is 2, but must be in the interval [0, 1] (in 'C:/Users/Studia/DOCUME~1/GitHub/PUBLIC~1/DATAAN~1/LAB2-I~1/code_2.stan', line 12, column 4 to column 25)
# 	Exception: bernoulli_lpmf: n[2] is 2, but must be in the interval [0, 1] (in 'C:/Users/Studia/DOCUME~1/GitHub/PUBLIC~1/DATAAN~1/LAB2-I~1/code_2.stan', line 12, column 4 to column 25)
# 	Exception: bernoulli_lpmf: n[2] is 2, but must be in the interval [0, 1] (in 'C:/Users/Studia/DOCUME~1/GitHub/PUBLIC~1/DATAAN~1/LAB2-I~1/code_2.stan', line 12, column 4 to column 25)
# 	Exception: bernoulli_lpmf: n[2] is 2, but must be in the interval [0, 1] (in 'C:/Users/Studia/DOCUME~1/GitHub/PUBLIC~1/DATAAN~1/LAB2-I~1/code_2.stan', line 12, column 4 to column 25)
# 	Exception: bernoulli_lpmf: n[2] is 2, but must be in the interval [0, 1] (in 'C:/Users/Studia/DOCUME~1/GitHub/PUBLIC~1/DATAAN~1/LAB2-I~1/code_2.stan', line 12, column 4 to column 25)
# 	Exception: bernoulli_lpmf: n[2] is 2, but must be in the interval [0, 1] (in 'C:/Users/Studia/DOCUME~1/GitHub/PUBLIC~1/DATAAN~1/LAB2-I~1/code_2.stan', line 12, column 4 to column 25)
# 	Exception: bernoulli_lpmf: n[2] is 2, but must be in the interval [0, 1] (in 'C:/Users/Studia/DOCUME~1/GitHub/PUBLIC~1/DATAAN~1/LAB2-I~1/code_2.stan', line 12, column 4 to column 25)
# 	Exception: bernoulli_lpmf: n[2] is 2, but must be in the interval [0, 1] (in 'C:/Users/Studia/DOCUME~1/GitHub/PUBLIC~1/DATAAN~1/LAB2-I~1/code_2.stan', line 12, column 4 to column 25)
# 	Exception: bernoulli_lpmf: n[2] is 2, but must be in the interval [0, 1] (in 'C:/Users/Studia/DOCUME~1/GitHub/PUBLIC~1/DATAAN~1/LAB2-I~1/code_2.stan', line 12, column 4 to column 25)
# 	Exception: bernoulli_lpmf: n[2] is 2, but must be in the interval [0, 1] (in 'C:/Users/Studia/DOCUME~1/GitHub/PUBLIC~1/DATAAN~1/LAB2-I~1/code_2.stan', line 12, column 4 to column 25)
# 	Exception: bernoulli_lpmf: n[2] is 2, but must be in the interval [0, 1] (in 'C:/Users/Studia/DOCUME~1/GitHub/PUBLIC~1/DATAAN~1/LAB2-I~1/code_2.stan', line 12, column 4 to column 25)
# 	Exception: bernoulli_lpmf: n[2] is 2, but must be in the interval [0, 1] (in 'C:/Users/Studia/DOCUME~1/GitHub/PUBLIC~1/DATAAN~1/LAB2-I~1/code_2.stan', line 12, column 4 to column 25)
# 	Exception: bernoulli_lpmf: n[2] is 2, but must be in the interval [0, 1] (in 'C:/Users/Studia/DOCUME~1/GitHub/PUBLIC~1/DATAAN~1/LAB2-I~1/code_2.stan', line 12, column 4 to column 25)
# 	Exception: bernoulli_lpmf: n[2] is 2, but must be in the interval [0, 1] (in 'C:/Users/Studia/DOCUME~1/GitHub/PUBLIC~1/DATAAN~1/LAB2-I~1/code_2.stan', line 12, column 4 to column 25)
# 	Exception: bernoulli_lpmf: n[2] is 2, but must be in the interval [0, 1] (in 'C:/Users/Studia/DOCUME~1/GitHub/PUBLIC~1/DATAAN~1/LAB2-I~1/code_2.stan', line 12, column 4 to column 25)
# 	Exception: bernoulli_lpmf: n[2] is 2, but must be in the interval [0, 1] (in 'C:/Users/Studia/DOCUME~1/GitHub/PUBLIC~1/DATAAN~1/LAB2-I~1/code_2.stan', line 12, column 4 to column 25)
# 	Exception: bernoulli_lpmf: n[2] is 2, but must be in the interval [0, 1] (in 'C:/Users/Studia/DOCUME~1/GitHub/PUBLIC~1/DATAAN~1/LAB2-I~1/code_2.stan', line 12, column 4 to column 25)
# 	Exception: bernoulli_lpmf: n[2] is 2, but must be in the interval [0, 1] (in 'C:/Users/Studia/DOCUME~1/GitHub/PUBLIC~1/DATAAN~1/LAB2-I~1/code_2.stan', line 12, column 4 to column 25)
# 	Exception: bernoulli_lpmf: n[2] is 2, but must be in the interval [0, 1] (in 'C:/Users/Studia/DOCUME~1/GitHub/PUBLIC~1/DATAAN~1/LAB2-I~1/code_2.stan', line 12, column 4 to column 25)
# 	Exception: bernoulli_lpmf: n[2] is 2, but must be in the interval [0, 1] (in 'C:/Users/Studia/DOCUME~1/GitHub/PUBLIC~1/DATAAN~1/LAB2-I~1/code_2.stan', line 12, column 4 to column 25)
# 	Exception: bernoulli_lpmf: n[2] is 2, but must be in the interval [0, 1] (in 'C:/Users/Studia/DOCUME~1/GitHub/PUBLIC~1/DATAAN~1/LAB2-I~1/code_2.stan', line 12, column 4 to column 25)
# 	Exception: bernoulli_lpmf: n[2] is 2, but must be in the interval [0, 1] (in 'C:/Users/Studia/DOCUME~1/GitHub/PUBLIC~1/DATAAN~1/LAB2-I~1/code_2.stan', line 12, column 4 to column 25)
# 	Exception: bernoulli_lpmf: n[2] is 2, but must be in the interval [0, 1] (in 'C:/Users/Studia/DOCUME~1/GitHub/PUBLIC~1/DATAAN~1/LAB2-I~1/code_2.stan', line 12, column 4 to column 25)
#
# chain_id 2:
# 	Exception: bernoulli_lpmf: n[2] is 2, but must be in the interval [0, 1] (in 'C:/Users/Studia/DOCUME~1/GitHub/PUBLIC~1/DATAAN~1/LAB2-I~1/code_2.stan', line 12, column 4 to column 25)
# 	Exception: bernoulli_lpmf: n[2] is 2, but must be in the interval [0, 1] (in 'C:/Users/Studia/DOCUME~1/GitHub/PUBLIC~1/DATAAN~1/LAB2-I~1/code_2.stan', line 12, column 4 to column 25)
# 	Exception: bernoulli_lpmf: n[2] is 2, but must be in the interval [0, 1] (in 'C:/Users/Studia/DOCUME~1/GitHub/PUBLIC~1/DATAAN~1/LAB2-I~1/code_2.stan', line 12, column 4 to column 25)
# 	Exception: bernoulli_lpmf: n[2] is 2, but must be in the interval [0, 1] (in 'C:/Users/Studia/DOCUME~1/GitHub/PUBLIC~1/DATAAN~1/LAB2-I~1/code_2.stan', line 12, column 4 to column 25)
# 	Exception: bernoulli_lpmf: n[2] is 2, but must be in the interval [0, 1] (in 'C:/Users/Studia/DOCUME~1/GitHub/PUBLIC~1/DATAAN~1/LAB2-I~1/code_2.stan', line 12, column 4 to column 25)
# 	Exception: bernoulli_lpmf: n[2] is 2, but must be in the interval [0, 1] (in 'C:/Users/Studia/DOCUME~1/GitHub/PUBLIC~1/DATAAN~1/LAB2-I~1/code_2.stan', line 12, column 4 to column 25)
# 	Exception: bernoulli_lpmf: n[2] is 2, but must be in the interval [0, 1] (in 'C:/Users/Studia/DOCUME~1/GitHub/PUBLIC~1/DATAAN~1/LAB2-I~1/code_2.stan', line 12, column 4 to column 25)
# 	Exception: bernoulli_lpmf: n[2] is 2, but must be in the interval [0, 1] (in 'C:/Users/Studia/DOCUME~1/GitHub/PUBLIC~1/DATAAN~1/LAB2-I~1/code_2.stan', line 12, column 4 to column 25)
# 	Exception: bernoulli_lpmf: n[2] is 2, but must be in the interval [0, 1] (in 'C:/Users/Studia/DOCUME~1/GitHub/PUBLIC~1/DATAAN~1/LAB2-I~1/code_2.stan', line 12, column 4 to column 25)
# 	Exception: bernoulli_lpmf: n[2] is 2, but must be in the interval [0, 1] (in 'C:/Users/Studia/DOCUME~1/GitHub/PUBLIC~1/DATAAN~1/LAB2-I~1/code_2.stan', line 12, column 4 to column 25)
# 	Exception: bernoulli_lpmf: n[2] is 2, but must be in the interval [0, 1] (in 'C:/Users/Studia/DOCUME~1/GitHub/PUBLIC~1/DATAAN~1/LAB2-I~1/code_2.stan', line 12, column 4 to column 25)
# 	Exception: bernoulli_lpmf: n[2] is 2, but must be in the interval [0, 1] (in 'C:/Users/Studia/DOCUME~1/GitHub/PUBLIC~1/DATAAN~1/LAB2-I~1/code_2.stan', line 12, column 4 to column 25)
# 	Exception: bernoulli_lpmf: n[2] is 2, but must be in the interval [0, 1] (in 'C:/Users/Studia/DOCUME~1/GitHub/PUBLIC~1/DATAAN~1/LAB2-I~1/code_2.stan', line 12, column 4 to column 25)
# 	Exception: bernoulli_lpmf: n[2] is 2, but must be in the interval [0, 1] (in 'C:/Users/Studia/DOCUME~1/GitHub/PUBLIC~1/DATAAN~1/LAB2-I~1/code_2.stan', line 12, column 4 to column 25)
# 	Exception: bernoulli_lpmf: n[2] is 2, but must be in the interval [0, 1] (in 'C:/Users/Studia/DOCUME~1/GitHub/PUBLIC~1/DATAAN~1/LAB2-I~1/code_2.stan', line 12, column 4 to column 25)
# 	Exception: bernoulli_lpmf: n[2] is 2, but must be in the interval [0, 1] (in 'C:/Users/Studia/DOCUME~1/GitHub/PUBLIC~1/DATAAN~1/LAB2-I~1/code_2.stan', line 12, column 4 to column 25)
# 	Exception: bernoulli_lpmf: n[2] is 2, but must be in the interval [0, 1] (in 'C:/Users/Studia/DOCUME~1/GitHub/PUBLIC~1/DATAAN~1/LAB2-I~1/code_2.stan', line 12, column 4 to column 25)
# 	Exception: bernoulli_lpmf: n[2] is 2, but must be in the interval [0, 1] (in 'C:/Users/Studia/DOCUME~1/GitHub/PUBLIC~1/DATAAN~1/LAB2-I~1/code_2.stan', line 12, column 4 to column 25)
# 	Exception: bernoulli_lpmf: n[2] is 2, but must be in the interval [0, 1] (in 'C:/Users/Studia/DOCUME~1/GitHub/PUBLIC~1/DATAAN~1/LAB2-I~1/code_2.stan', line 12, column 4 to column 25)
# 	Exception: bernoulli_lpmf: n[2] is 2, but must be in the interval [0, 1] (in 'C:/Users/Studia/DOCUME~1/GitHub/PUBLIC~1/DATAAN~1/LAB2-I~1/code_2.stan', line 12, column 4 to column 25)
# 	Exception: bernoulli_lpmf: n[2] is 2, but must be in the interval [0, 1] (in 'C:/Users/Studia/DOCUME~1/GitHub/PUBLIC~1/DATAAN~1/LAB2-I~1/code_2.stan', line 12, column 4 to column 25)
# 	Exception: bernoulli_lpmf: n[2] is 2, but must be in the interval [0, 1] (in 'C:/Users/Studia/DOCUME~1/GitHub/PUBLIC~1/DATAAN~1/LAB2-I~1/code_2.stan', line 12, column 4 to column 25)
# 	Exception: bernoulli_lpmf: n[2] is 2, but must be in the interval [0, 1] (in 'C:/Users/Studia/DOCUME~1/GitHub/PUBLIC~1/DATAAN~1/LAB2-I~1/code_2.stan', line 12, column 4 to column 25)
# 	Exception: bernoulli_lpmf: n[2] is 2, but must be in the interval [0, 1] (in 'C:/Users/Studia/DOCUME~1/GitHub/PUBLIC~1/DATAAN~1/LAB2-I~1/code_2.stan', line 12, column 4 to column 25)
# 	Exception: bernoulli_lpmf: n[2] is 2, but must be in the interval [0, 1] (in 'C:/Users/Studia/DOCUME~1/GitHub/PUBLIC~1/DATAAN~1/LAB2-I~1/code_2.stan', line 12, column 4 to column 25)
# 	Exception: bernoulli_lpmf: n[2] is 2, but must be in the interval [0, 1] (in 'C:/Users/Studia/DOCUME~1/GitHub/PUBLIC~1/DATAAN~1/LAB2-I~1/code_2.stan', line 12, column 4 to column 25)
# 	Exception: bernoulli_lpmf: n[2] is 2, but must be in the interval [0, 1] (in 'C:/Users/Studia/DOCUME~1/GitHub/PUBLIC~1/DATAAN~1/LAB2-I~1/code_2.stan', line 12, column 4 to column 25)
# 	Exception: bernoulli_lpmf: n[2] is 2, but must be in the interval [0, 1] (in 'C:/Users/Studia/DOCUME~1/GitHub/PUBLIC~1/DATAAN~1/LAB2-I~1/code_2.stan', line 12, column 4 to column 25)
# 	Exception: bernoulli_lpmf: n[2] is 2, but must be in the interval [0, 1] (in 'C:/Users/Studia/DOCUME~1/GitHub/PUBLIC~1/DATAAN~1/LAB2-I~1/code_2.stan', line 12, column 4 to column 25)
# 	Exception: bernoulli_lpmf: n[2] is 2, but must be in the interval [0, 1] (in 'C:/Users/Studia/DOCUME~1/GitHub/PUBLIC~1/DATAAN~1/LAB2-I~1/code_2.stan', line 12, column 4 to column 25)
# 	Exception: bernoulli_lpmf: n[2] is 2, but must be in the interval [0, 1] (in 'C:/Users/Studia/DOCUME~1/GitHub/PUBLIC~1/DATAAN~1/LAB2-I~1/code_2.stan', line 12, column 4 to column 25)
# 	Exception: bernoulli_lpmf: n[2] is 2, but must be in the interval [0, 1] (in 'C:/Users/Studia/DOCUME~1/GitHub/PUBLIC~1/DATAAN~1/LAB2-I~1/code_2.stan', line 12, column 4 to column 25)
# 	Exception: bernoulli_lpmf: n[2] is 2, but must be in the interval [0, 1] (in 'C:/Users/Studia/DOCUME~1/GitHub/PUBLIC~1/DATAAN~1/LAB2-I~1/code_2.stan', line 12, column 4 to column 25)
# 	Exception: bernoulli_lpmf: n[2] is 2, but must be in the interval [0, 1] (in 'C:/Users/Studia/DOCUME~1/GitHub/PUBLIC~1/DATAAN~1/LAB2-I~1/code_2.stan', line 12, column 4 to column 25)
# 	Exception: bernoulli_lpmf: n[2] is 2, but must be in the interval [0, 1] (in 'C:/Users/Studia/DOCUME~1/GitHub/PUBLIC~1/DATAAN~1/LAB2-I~1/code_2.stan', line 12, column 4 to column 25)
# 	Exception: bernoulli_lpmf: n[2] is 2, but must be in the interval [0, 1] (in 'C:/Users/Studia/DOCUME~1/GitHub/PUBLIC~1/DATAAN~1/LAB2-I~1/code_2.stan', line 12, column 4 to column 25)
# 	Exception: bernoulli_lpmf: n[2] is 2, but must be in the interval [0, 1] (in 'C:/Users/Studia/DOCUME~1/GitHub/PUBLIC~1/DATAAN~1/LAB2-I~1/code_2.stan', line 12, column 4 to column 25)
# 	Exception: bernoulli_lpmf: n[2] is 2, but must be in the interval [0, 1] (in 'C:/Users/Studia/DOCUME~1/GitHub/PUBLIC~1/DATAAN~1/LAB2-I~1/code_2.stan', line 12, column 4 to column 25)
# 	Exception: bernoulli_lpmf: n[2] is 2, but must be in the interval [0, 1] (in 'C:/Users/Studia/DOCUME~1/GitHub/PUBLIC~1/DATAAN~1/LAB2-I~1/code_2.stan', line 12, column 4 to column 25)
# 	Exception: bernoulli_lpmf: n[2] is 2, but must be in the interval [0, 1] (in 'C:/Users/Studia/DOCUME~1/GitHub/PUBLIC~1/DATAAN~1/LAB2-I~1/code_2.stan', line 12, column 4 to column 25)
# 	Exception: bernoulli_lpmf: n[2] is 2, but must be in the interval [0, 1] (in 'C:/Users/Studia/DOCUME~1/GitHub/PUBLIC~1/DATAAN~1/LAB2-I~1/code_2.stan', line 12, column 4 to column 25)
# 	Exception: bernoulli_lpmf: n[2] is 2, but must be in the interval [0, 1] (in 'C:/Users/Studia/DOCUME~1/GitHub/PUBLIC~1/DATAAN~1/LAB2-I~1/code_2.stan', line 12, column 4 to column 25)
# 	Exception: bernoulli_lpmf: n[2] is 2, but must be in the interval [0, 1] (in 'C:/Users/Studia/DOCUME~1/GitHub/PUBLIC~1/DATAAN~1/LAB2-I~1/code_2.stan', line 12, column 4 to column 25)
# 	Exception: bernoulli_lpmf: n[2] is 2, but must be in the interval [0, 1] (in 'C:/Users/Studia/DOCUME~1/GitHub/PUBLIC~1/DATAAN~1/LAB2-I~1/code_2.stan', line 12, column 4 to column 25)
# 	Exception: bernoulli_lpmf: n[2] is 2, but must be in the interval [0, 1] (in 'C:/Users/Studia/DOCUME~1/GitHub/PUBLIC~1/DATAAN~1/LAB2-I~1/code_2.stan', line 12, column 4 to column 25)
# 	Exception: bernoulli_lpmf: n[2] is 2, but must be in the interval [0, 1] (in 'C:/Users/Studia/DOCUME~1/GitHub/PUBLIC~1/DATAAN~1/LAB2-I~1/code_2.stan', line 12, column 4 to column 25)
# 	Exception: bernoulli_lpmf: n[2] is 2, but must be in the interval [0, 1] (in 'C:/Users/Studia/DOCUME~1/GitHub/PUBLIC~1/DATAAN~1/LAB2-I~1/code_2.stan', line 12, column 4 to column 25)
# 	Exception: bernoulli_lpmf: n[2] is 2, but must be in the interval [0, 1] (in 'C:/Users/Studia/DOCUME~1/GitHub/PUBLIC~1/DATAAN~1/LAB2-I~1/code_2.stan', line 12, column 4 to column 25)
# 	Exception: bernoulli_lpmf: n[2] is 2, but must be in the interval [0, 1] (in 'C:/Users/Studia/DOCUME~1/GitHub/PUBLIC~1/DATAAN~1/LAB2-I~1/code_2.stan', line 12, column 4 to column 25)
# 	Exception: bernoulli_lpmf: n[2] is 2, but must be in the interval [0, 1] (in 'C:/Users/Studia/DOCUME~1/GitHub/PUBLIC~1/DATAAN~1/LAB2-I~1/code_2.stan', line 12, column 4 to column 25)
# 	Exception: bernoulli_lpmf: n[2] is 2, but must be in the interval [0, 1] (in 'C:/Users/Studia/DOCUME~1/GitHub/PUBLIC~1/DATAAN~1/LAB2-I~1/code_2.stan', line 12, column 4 to column 25)
# 	Exception: bernoulli_lpmf: n[2] is 2, but must be in the interval [0, 1] (in 'C:/Users/Studia/DOCUME~1/GitHub/PUBLIC~1/DATAAN~1/LAB2-I~1/code_2.stan', line 12, column 4 to column 25)
# 	Exception: bernoulli_lpmf: n[2] is 2, but must be in the interval [0, 1] (in 'C:/Users/Studia/DOCUME~1/GitHub/PUBLIC~1/DATAAN~1/LAB2-I~1/code_2.stan', line 12, column 4 to column 25)
# 	Exception: bernoulli_lpmf: n[2] is 2, but must be in the interval [0, 1] (in 'C:/Users/Studia/DOCUME~1/GitHub/PUBLIC~1/DATAAN~1/LAB2-I~1/code_2.stan', line 12, column 4 to column 25)
# 	Exception: bernoulli_lpmf: n[2] is 2, but must be in the interval [0, 1] (in 'C:/Users/Studia/DOCUME~1/GitHub/PUBLIC~1/DATAAN~1/LAB2-I~1/code_2.stan', line 12, column 4 to column 25)
# 	Exception: bernoulli_lpmf: n[2] is 2, but must be in the interval [0, 1] (in 'C:/Users/Studia/DOCUME~1/GitHub/PUBLIC~1/DATAAN~1/LAB2-I~1/code_2.stan', line 12, column 4 to column 25)
# 	Exception: bernoulli_lpmf: n[2] is 2, but must be in the interval [0, 1] (in 'C:/Users/Studia/DOCUME~1/GitHub/PUBLIC~1/DATAAN~1/LAB2-I~1/code_2.stan', line 12, column 4 to column 25)
# 	Exception: bernoulli_lpmf: n[2] is 2, but must be in the interval [0, 1] (in 'C:/Users/Studia/DOCUME~1/GitHub/PUBLIC~1/DATAAN~1/LAB2-I~1/code_2.stan', line 12, column 4 to column 25)
# 	Exception: bernoulli_lpmf: n[2] is 2, but must be in the interval [0, 1] (in 'C:/Users/Studia/DOCUME~1/GitHub/PUBLIC~1/DATAAN~1/LAB2-I~1/code_2.stan', line 12, column 4 to column 25)
# 	Exception: bernoulli_lpmf: n[2] is 2, but must be in the interval [0, 1] (in 'C:/Users/Studia/DOCUME~1/GitHub/PUBLIC~1/DATAAN~1/LAB2-I~1/code_2.stan', line 12, column 4 to column 25)
# 	Exception: bernoulli_lpmf: n[2] is 2, but must be in the interval [0, 1] (in 'C:/Users/Studia/DOCUME~1/GitHub/PUBLIC~1/DATAAN~1/LAB2-I~1/code_2.stan', line 12, column 4 to column 25)
# 	Exception: bernoulli_lpmf: n[2] is 2, but must be in the interval [0, 1] (in 'C:/Users/Studia/DOCUME~1/GitHub/PUBLIC~1/DATAAN~1/LAB2-I~1/code_2.stan', line 12, column 4 to column 25)
# 	Exception: bernoulli_lpmf: n[2] is 2, but must be in the interval [0, 1] (in 'C:/Users/Studia/DOCUME~1/GitHub/PUBLIC~1/DATAAN~1/LAB2-I~1/code_2.stan', line 12, column 4 to column 25)
# 	Exception: bernoulli_lpmf: n[2] is 2, but must be in the interval [0, 1] (in 'C:/Users/Studia/DOCUME~1/GitHub/PUBLIC~1/DATAAN~1/LAB2-I~1/code_2.stan', line 12, column 4 to column 25)
# 	Exception: bernoulli_lpmf: n[2] is 2, but must be in the interval [0, 1] (in 'C:/Users/Studia/DOCUME~1/GitHub/PUBLIC~1/DATAAN~1/LAB2-I~1/code_2.stan', line 12, column 4 to column 25)
# 	Exception: bernoulli_lpmf: n[2] is 2, but must be in the interval [0, 1] (in 'C:/Users/Studia/DOCUME~1/GitHub/PUBLIC~1/DATAAN~1/LAB2-I~1/code_2.stan', line 12, column 4 to column 25)
# 	Exception: bernoulli_lpmf: n[2] is 2, but must be in the interval [0, 1] (in 'C:/Users/Studia/DOCUME~1/GitHub/PUBLIC~1/DATAAN~1/LAB2-I~1/code_2.stan', line 12, column 4 to column 25)
# 	Exception: bernoulli_lpmf: n[2] is 2, but must be in the interval [0, 1] (in 'C:/Users/Studia/DOCUME~1/GitHub/PUBLIC~1/DATAAN~1/LAB2-I~1/code_2.stan', line 12, column 4 to column 25)
# 	Exception: bernoulli_lpmf: n[2] is 2, but must be in the interval [0, 1] (in 'C:/Users/Studia/DOCUME~1/GitHub/PUBLIC~1/DATAAN~1/LAB2-I~1/code_2.stan', line 12, column 4 to column 25)
# 	Exception: bernoulli_lpmf: n[2] is 2, but must be in the interval [0, 1] (in 'C:/Users/Studia/DOCUME~1/GitHub/PUBLIC~1/DATAAN~1/LAB2-I~1/code_2.stan', line 12, column 4 to column 25)
# 	Exception: bernoulli_lpmf: n[2] is 2, but must be in the interval [0, 1] (in 'C:/Users/Studia/DOCUME~1/GitHub/PUBLIC~1/DATAAN~1/LAB2-I~1/code_2.stan', line 12, column 4 to column 25)
# 	Exception: bernoulli_lpmf: n[2] is 2, but must be in the interval [0, 1] (in 'C:/Users/Studia/DOCUME~1/GitHub/PUBLIC~1/DATAAN~1/LAB2-I~1/code_2.stan', line 12, column 4 to column 25)
# 	Exception: bernoulli_lpmf: n[2] is 2, but must be in the interval [0, 1] (in 'C:/Users/Studia/DOCUME~1/GitHub/PUBLIC~1/DATAAN~1/LAB2-I~1/code_2.stan', line 12, column 4 to column 25)
# 	Exception: bernoulli_lpmf: n[2] is 2, but must be in the interval [0, 1] (in 'C:/Users/Studia/DOCUME~1/GitHub/PUBLIC~1/DATAAN~1/LAB2-I~1/code_2.stan', line 12, column 4 to column 25)
# 	Exception: bernoulli_lpmf: n[2] is 2, but must be in the interval [0, 1] (in 'C:/Users/Studia/DOCUME~1/GitHub/PUBLIC~1/DATAAN~1/LAB2-I~1/code_2.stan', line 12, column 4 to column 25)
# 	Exception: bernoulli_lpmf: n[2] is 2, but must be in the interval [0, 1] (in 'C:/Users/Studia/DOCUME~1/GitHub/PUBLIC~1/DATAAN~1/LAB2-I~1/code_2.stan', line 12, column 4 to column 25)
# 	Exception: bernoulli_lpmf: n[2] is 2, but must be in the interval [0, 1] (in 'C:/Users/Studia/DOCUME~1/GitHub/PUBLIC~1/DATAAN~1/LAB2-I~1/code_2.stan', line 12, column 4 to column 25)
# 	Exception: bernoulli_lpmf: n[2] is 2, but must be in the interval [0, 1] (in 'C:/Users/Studia/DOCUME~1/GitHub/PUBLIC~1/DATAAN~1/LAB2-I~1/code_2.stan', line 12, column 4 to column 25)
# 	Exception: bernoulli_lpmf: n[2] is 2, but must be in the interval [0, 1] (in 'C:/Users/Studia/DOCUME~1/GitHub/PUBLIC~1/DATAAN~1/LAB2-I~1/code_2.stan', line 12, column 4 to column 25)
# 	Exception: bernoulli_lpmf: n[2] is 2, but must be in the interval [0, 1] (in 'C:/Users/Studia/DOCUME~1/GitHub/PUBLIC~1/DATAAN~1/LAB2-I~1/code_2.stan', line 12, column 4 to column 25)
# 	Exception: bernoulli_lpmf: n[2] is 2, but must be in the interval [0, 1] (in 'C:/Users/Studia/DOCUME~1/GitHub/PUBLIC~1/DATAAN~1/LAB2-I~1/code_2.stan', line 12, column 4 to column 25)
# 	Exception: bernoulli_lpmf: n[2] is 2, but must be in the interval [0, 1] (in 'C:/Users/Studia/DOCUME~1/GitHub/PUBLIC~1/DATAAN~1/LAB2-I~1/code_2.stan', line 12, column 4 to column 25)
# 	Exception: bernoulli_lpmf: n[2] is 2, but must be in the interval [0, 1] (in 'C:/Users/Studia/DOCUME~1/GitHub/PUBLIC~1/DATAAN~1/LAB2-I~1/code_2.stan', line 12, column 4 to column 25)
# 	Exception: bernoulli_lpmf: n[2] is 2, but must be in the interval [0, 1] (in 'C:/Users/Studia/DOCUME~1/GitHub/PUBLIC~1/DATAAN~1/LAB2-I~1/code_2.stan', line 12, column 4 to column 25)
# 	Exception: bernoulli_lpmf: n[2] is 2, but must be in the interval [0, 1] (in 'C:/Users/Studia/DOCUME~1/GitHub/PUBLIC~1/DATAAN~1/LAB2-I~1/code_2.stan', line 12, column 4 to column 25)
# 	Exception: bernoulli_lpmf: n[2] is 2, but must be in the interval [0, 1] (in 'C:/Users/Studia/DOCUME~1/GitHub/PUBLIC~1/DATAAN~1/LAB2-I~1/code_2.stan', line 12, column 4 to column 25)
# 	Exception: bernoulli_lpmf: n[2] is 2, but must be in the interval [0, 1] (in 'C:/Users/Studia/DOCUME~1/GitHub/PUBLIC~1/DATAAN~1/LAB2-I~1/code_2.stan', line 12, column 4 to column 25)
# 	Exception: bernoulli_lpmf: n[2] is 2, but must be in the interval [0, 1] (in 'C:/Users/Studia/DOCUME~1/GitHub/PUBLIC~1/DATAAN~1/LAB2-I~1/code_2.stan', line 12, column 4 to column 25)
# 	Exception: bernoulli_lpmf: n[2] is 2, but must be in the interval [0, 1] (in 'C:/Users/Studia/DOCUME~1/GitHub/PUBLIC~1/DATAAN~1/LAB2-I~1/code_2.stan', line 12, column 4 to column 25)
# 	Exception: bernoulli_lpmf: n[2] is 2, but must be in the interval [0, 1] (in 'C:/Users/Studia/DOCUME~1/GitHub/PUBLIC~1/DATAAN~1/LAB2-I~1/code_2.stan', line 12, column 4 to column 25)
# 	Exception: bernoulli_lpmf: n[2] is 2, but must be in the interval [0, 1] (in 'C:/Users/Studia/DOCUME~1/GitHub/PUBLIC~1/DATAAN~1/LAB2-I~1/code_2.stan', line 12, column 4 to column 25)
# 	Exception: bernoulli_lpmf: n[2] is 2, but must be in the interval [0, 1] (in 'C:/Users/Studia/DOCUME~1/GitHub/PUBLIC~1/DATAAN~1/LAB2-I~1/code_2.stan', line 12, column 4 to column 25)
# 	Exception: bernoulli_lpmf: n[2] is 2, but must be in the interval [0, 1] (in 'C:/Users/Studia/DOCUME~1/GitHub/PUBLIC~1/DATAAN~1/LAB2-I~1/code_2.stan', line 12, column 4 to column 25)
# 	Exception: bernoulli_lpmf: n[2] is 2, but must be in the interval [0, 1] (in 'C:/Users/Studia/DOCUME~1/GitHub/PUBLIC~1/DATAAN~1/LAB2-I~1/code_2.stan', line 12, column 4 to column 25)
# 	Exception: bernoulli_lpmf: n[2] is 2, but must be in the interval [0, 1] (in 'C:/Users/Studia/DOCUME~1/GitHub/PUBLIC~1/DATAAN~1/LAB2-I~1/code_2.stan', line 12, column 4 to column 25)
# 	Exception: bernoulli_lpmf: n[2] is 2, but must be in the interval [0, 1] (in 'C:/Users/Studia/DOCUME~1/GitHub/PUBLIC~1/DATAAN~1/LAB2-I~1/code_2.stan', line 12, column 4 to column 25)
# 	Exception: bernoulli_lpmf: n[2] is 2, but must be in the interval [0, 1] (in 'C:/Users/Studia/DOCUME~1/GitHub/PUBLIC~1/DATAAN~1/LAB2-I~1/code_2.stan', line 12, column 4 to column 25)
# 	Exception: bernoulli_lpmf: n[2] is 2, but must be in the interval [0, 1] (in 'C:/Users/Studia/DOCUME~1/GitHub/PUBLIC~1/DATAAN~1/LAB2-I~1/code_2.stan', line 12, column 4 to column 25)
# 	Exception: bernoulli_lpmf: n[2] is 2, but must be in the interval [0, 1] (in 'C:/Users/Studia/DOCUME~1/GitHub/PUBLIC~1/DATAAN~1/LAB2-I~1/code_2.stan', line 12, column 4 to column 25)
# 	Exception: bernoulli_lpmf: n[2] is 2, but must be in the interval [0, 1] (in 'C:/Users/Studia/DOCUME~1/GitHub/PUBLIC~1/DATAAN~1/LAB2-I~1/code_2.stan', line 12, column 4 to column 25)
#
# chain_id 3:
# 	Exception: bernoulli_lpmf: n[2] is 2, but must be in the interval [0, 1] (in 'C:/Users/Studia/DOCUME~1/GitHub/PUBLIC~1/DATAAN~1/LAB2-I~1/code_2.stan', line 12, column 4 to column 25)
# 	Exception: bernoulli_lpmf: n[2] is 2, but must be in the interval [0, 1] (in 'C:/Users/Studia/DOCUME~1/GitHub/PUBLIC~1/DATAAN~1/LAB2-I~1/code_2.stan', line 12, column 4 to column 25)
# 	Exception: bernoulli_lpmf: n[2] is 2, but must be in the interval [0, 1] (in 'C:/Users/Studia/DOCUME~1/GitHub/PUBLIC~1/DATAAN~1/LAB2-I~1/code_2.stan', line 12, column 4 to column 25)
# 	Exception: bernoulli_lpmf: n[2] is 2, but must be in the interval [0, 1] (in 'C:/Users/Studia/DOCUME~1/GitHub/PUBLIC~1/DATAAN~1/LAB2-I~1/code_2.stan', line 12, column 4 to column 25)
# 	Exception: bernoulli_lpmf: n[2] is 2, but must be in the interval [0, 1] (in 'C:/Users/Studia/DOCUME~1/GitHub/PUBLIC~1/DATAAN~1/LAB2-I~1/code_2.stan', line 12, column 4 to column 25)
# 	Exception: bernoulli_lpmf: n[2] is 2, but must be in the interval [0, 1] (in 'C:/Users/Studia/DOCUME~1/GitHub/PUBLIC~1/DATAAN~1/LAB2-I~1/code_2.stan', line 12, column 4 to column 25)
# 	Exception: bernoulli_lpmf: n[2] is 2, but must be in the interval [0, 1] (in 'C:/Users/Studia/DOCUME~1/GitHub/PUBLIC~1/DATAAN~1/LAB2-I~1/code_2.stan', line 12, column 4 to column 25)
# 	Exception: bernoulli_lpmf: n[2] is 2, but must be in the interval [0, 1] (in 'C:/Users/Studia/DOCUME~1/GitHub/PUBLIC~1/DATAAN~1/LAB2-I~1/code_2.stan', line 12, column 4 to column 25)
# 	Exception: bernoulli_lpmf: n[2] is 2, but must be in the interval [0, 1] (in 'C:/Users/Studia/DOCUME~1/GitHub/PUBLIC~1/DATAAN~1/LAB2-I~1/code_2.stan', line 12, column 4 to column 25)
# 	Exception: bernoulli_lpmf: n[2] is 2, but must be in the interval [0, 1] (in 'C:/Users/Studia/DOCUME~1/GitHub/PUBLIC~1/DATAAN~1/LAB2-I~1/code_2.stan', line 12, column 4 to column 25)
# 	Exception: bernoulli_lpmf: n[2] is 2, but must be in the interval [0, 1] (in 'C:/Users/Studia/DOCUME~1/GitHub/PUBLIC~1/DATAAN~1/LAB2-I~1/code_2.stan', line 12, column 4 to column 25)
# 	Exception: bernoulli_lpmf: n[2] is 2, but must be in the interval [0, 1] (in 'C:/Users/Studia/DOCUME~1/GitHub/PUBLIC~1/DATAAN~1/LAB2-I~1/code_2.stan', line 12, column 4 to column 25)
# 	Exception: bernoulli_lpmf: n[2] is 2, but must be in the interval [0, 1] (in 'C:/Users/Studia/DOCUME~1/GitHub/PUBLIC~1/DATAAN~1/LAB2-I~1/code_2.stan', line 12, column 4 to column 25)
# 	Exception: bernoulli_lpmf: n[2] is 2, but must be in the interval [0, 1] (in 'C:/Users/Studia/DOCUME~1/GitHub/PUBLIC~1/DATAAN~1/LAB2-I~1/code_2.stan', line 12, column 4 to column 25)
# 	Exception: bernoulli_lpmf: n[2] is 2, but must be in the interval [0, 1] (in 'C:/Users/Studia/DOCUME~1/GitHub/PUBLIC~1/DATAAN~1/LAB2-I~1/code_2.stan', line 12, column 4 to column 25)
# 	Exception: bernoulli_lpmf: n[2] is 2, but must be in the interval [0, 1] (in 'C:/Users/Studia/DOCUME~1/GitHub/PUBLIC~1/DATAAN~1/LAB2-I~1/code_2.stan', line 12, column 4 to column 25)
# 	Exception: bernoulli_lpmf: n[2] is 2, but must be in the interval [0, 1] (in 'C:/Users/Studia/DOCUME~1/GitHub/PUBLIC~1/DATAAN~1/LAB2-I~1/code_2.stan', line 12, column 4 to column 25)
# 	Exception: bernoulli_lpmf: n[2] is 2, but must be in the interval [0, 1] (in 'C:/Users/Studia/DOCUME~1/GitHub/PUBLIC~1/DATAAN~1/LAB2-I~1/code_2.stan', line 12, column 4 to column 25)
# 	Exception: bernoulli_lpmf: n[2] is 2, but must be in the interval [0, 1] (in 'C:/Users/Studia/DOCUME~1/GitHub/PUBLIC~1/DATAAN~1/LAB2-I~1/code_2.stan', line 12, column 4 to column 25)
# 	Exception: bernoulli_lpmf: n[2] is 2, but must be in the interval [0, 1] (in 'C:/Users/Studia/DOCUME~1/GitHub/PUBLIC~1/DATAAN~1/LAB2-I~1/code_2.stan', line 12, column 4 to column 25)
# 	Exception: bernoulli_lpmf: n[2] is 2, but must be in the interval [0, 1] (in 'C:/Users/Studia/DOCUME~1/GitHub/PUBLIC~1/DATAAN~1/LAB2-I~1/code_2.stan', line 12, column 4 to column 25)
# 	Exception: bernoulli_lpmf: n[2] is 2, but must be in the interval [0, 1] (in 'C:/Users/Studia/DOCUME~1/GitHub/PUBLIC~1/DATAAN~1/LAB2-I~1/code_2.stan', line 12, column 4 to column 25)
# 	Exception: bernoulli_lpmf: n[2] is 2, but must be in the interval [0, 1] (in 'C:/Users/Studia/DOCUME~1/GitHub/PUBLIC~1/DATAAN~1/LAB2-I~1/code_2.stan', line 12, column 4 to column 25)
# 	Exception: bernoulli_lpmf: n[2] is 2, but must be in the interval [0, 1] (in 'C:/Users/Studia/DOCUME~1/GitHub/PUBLIC~1/DATAAN~1/LAB2-I~1/code_2.stan', line 12, column 4 to column 25)
# 	Exception: bernoulli_lpmf: n[2] is 2, but must be in the interval [0, 1] (in 'C:/Users/Studia/DOCUME~1/GitHub/PUBLIC~1/DATAAN~1/LAB2-I~1/code_2.stan', line 12, column 4 to column 25)
# 	Exception: bernoulli_lpmf: n[2] is 2, but must be in the interval [0, 1] (in 'C:/Users/Studia/DOCUME~1/GitHub/PUBLIC~1/DATAAN~1/LAB2-I~1/code_2.stan', line 12, column 4 to column 25)
# 	Exception: bernoulli_lpmf: n[2] is 2, but must be in the interval [0, 1] (in 'C:/Users/Studia/DOCUME~1/GitHub/PUBLIC~1/DATAAN~1/LAB2-I~1/code_2.stan', line 12, column 4 to column 25)
# 	Exception: bernoulli_lpmf: n[2] is 2, but must be in the interval [0, 1] (in 'C:/Users/Studia/DOCUME~1/GitHub/PUBLIC~1/DATAAN~1/LAB2-I~1/code_2.stan', line 12, column 4 to column 25)
# 	Exception: bernoulli_lpmf: n[2] is 2, but must be in the interval [0, 1] (in 'C:/Users/Studia/DOCUME~1/GitHub/PUBLIC~1/DATAAN~1/LAB2-I~1/code_2.stan', line 12, column 4 to column 25)
# 	Exception: bernoulli_lpmf: n[2] is 2, but must be in the interval [0, 1] (in 'C:/Users/Studia/DOCUME~1/GitHub/PUBLIC~1/DATAAN~1/LAB2-I~1/code_2.stan', line 12, column 4 to column 25)
# 	Exception: bernoulli_lpmf: n[2] is 2, but must be in the interval [0, 1] (in 'C:/Users/Studia/DOCUME~1/GitHub/PUBLIC~1/DATAAN~1/LAB2-I~1/code_2.stan', line 12, column 4 to column 25)
# 	Exception: bernoulli_lpmf: n[2] is 2, but must be in the interval [0, 1] (in 'C:/Users/Studia/DOCUME~1/GitHub/PUBLIC~1/DATAAN~1/LAB2-I~1/code_2.stan', line 12, column 4 to column 25)
# 	Exception: bernoulli_lpmf: n[2] is 2, but must be in the interval [0, 1] (in 'C:/Users/Studia/DOCUME~1/GitHub/PUBLIC~1/DATAAN~1/LAB2-I~1/code_2.stan', line 12, column 4 to column 25)
# 	Exception: bernoulli_lpmf: n[2] is 2, but must be in the interval [0, 1] (in 'C:/Users/Studia/DOCUME~1/GitHub/PUBLIC~1/DATAAN~1/LAB2-I~1/code_2.stan', line 12, column 4 to column 25)
# 	Exception: bernoulli_lpmf: n[2] is 2, but must be in the interval [0, 1] (in 'C:/Users/Studia/DOCUME~1/GitHub/PUBLIC~1/DATAAN~1/LAB2-I~1/code_2.stan', line 12, column 4 to column 25)
# 	Exception: bernoulli_lpmf: n[2] is 2, but must be in the interval [0, 1] (in 'C:/Users/Studia/DOCUME~1/GitHub/PUBLIC~1/DATAAN~1/LAB2-I~1/code_2.stan', line 12, column 4 to column 25)
# 	Exception: bernoulli_lpmf: n[2] is 2, but must be in the interval [0, 1] (in 'C:/Users/Studia/DOCUME~1/GitHub/PUBLIC~1/DATAAN~1/LAB2-I~1/code_2.stan', line 12, column 4 to column 25)
# 	Exception: bernoulli_lpmf: n[2] is 2, but must be in the interval [0, 1] (in 'C:/Users/Studia/DOCUME~1/GitHub/PUBLIC~1/DATAAN~1/LAB2-I~1/code_2.stan', line 12, column 4 to column 25)
# 	Exception: bernoulli_lpmf: n[2] is 2, but must be in the interval [0, 1] (in 'C:/Users/Studia/DOCUME~1/GitHub/PUBLIC~1/DATAAN~1/LAB2-I~1/code_2.stan', line 12, column 4 to column 25)
# 	Exception: bernoulli_lpmf: n[2] is 2, but must be in the interval [0, 1] (in 'C:/Users/Studia/DOCUME~1/GitHub/PUBLIC~1/DATAAN~1/LAB2-I~1/code_2.stan', line 12, column 4 to column 25)
# 	Exception: bernoulli_lpmf: n[2] is 2, but must be in the interval [0, 1] (in 'C:/Users/Studia/DOCUME~1/GitHub/PUBLIC~1/DATAAN~1/LAB2-I~1/code_2.stan', line 12, column 4 to column 25)
# 	Exception: bernoulli_lpmf: n[2] is 2, but must be in the interval [0, 1] (in 'C:/Users/Studia/DOCUME~1/GitHub/PUBLIC~1/DATAAN~1/LAB2-I~1/code_2.stan', line 12, column 4 to column 25)
# 	Exception: bernoulli_lpmf: n[2] is 2, but must be in the interval [0, 1] (in 'C:/Users/Studia/DOCUME~1/GitHub/PUBLIC~1/DATAAN~1/LAB2-I~1/code_2.stan', line 12, column 4 to column 25)
# 	Exception: bernoulli_lpmf: n[2] is 2, but must be in the interval [0, 1] (in 'C:/Users/Studia/DOCUME~1/GitHub/PUBLIC~1/DATAAN~1/LAB2-I~1/code_2.stan', line 12, column 4 to column 25)
# 	Exception: bernoulli_lpmf: n[2] is 2, but must be in the interval [0, 1] (in 'C:/Users/Studia/DOCUME~1/GitHub/PUBLIC~1/DATAAN~1/LAB2-I~1/code_2.stan', line 12, column 4 to column 25)
# 	Exception: bernoulli_lpmf: n[2] is 2, but must be in the interval [0, 1] (in 'C:/Users/Studia/DOCUME~1/GitHub/PUBLIC~1/DATAAN~1/LAB2-I~1/code_2.stan', line 12, column 4 to column 25)
# ...
# 	Exception: bernoulli_lpmf: n[2] is 2, but must be in the interval [0, 1] (in 'C:/Users/Studia/DOCUME~1/GitHub/PUBLIC~1/DATAAN~1/LAB2-I~1/code_2.stan', line 12, column 4 to column 25)
# 	Exception: bernoulli_lpmf: n[2] is 2, but must be in the interval [0, 1] (in 'C:/Users/Studia/DOCUME~1/GitHub/PUBLIC~1/DATAAN~1/LAB2-I~1/code_2.stan', line 12, column 4 to column 25)
# 	Exception: bernoulli_lpmf: n[2] is 2, but must be in the interval [0, 1] (in 'C:/Users/Studia/DOCUME~1/GitHub/PUBLIC~1/DATAAN~1/LAB2-I~1/code_2.stan', line 12, column 4 to column 25)
# 	Exception: bernoulli_lpmf: n[2] is 2, but must be in the interval [0, 1] (in 'C:/Users/Studia/DOCUME~1/GitHub/PUBLIC~1/DATAAN~1/LAB2-I~1/code_2.stan', line 12, column 4 to column 25)
# 	Exception: bernoulli_lpmf: n[2] is 2, but must be in the interval [0, 1] (in 'C:/Users/Studia/DOCUME~1/GitHub/PUBLIC~1/DATAAN~1/LAB2-I~1/code_2.stan', line 12, column 4 to column 25)
# 	Exception: bernoulli_lpmf: n[2] is 2, but must be in the interval [0, 1] (in 'C:/Users/Studia/DOCUME~1/GitHub/PUBLIC~1/DATAAN~1/LAB2-I~1/code_2.stan', line 12, column 4 to column 25)
# 	Exception: bernoulli_lpmf: n[2] is 2, but must be in the interval [0, 1] (in 'C:/Users/Studia/DOCUME~1/GitHub/PUBLIC~1/DATAAN~1/LAB2-I~1/code_2.stan', line 12, column 4 to column 25)
# 	Exception: bernoulli_lpmf: n[2] is 2, but must be in the interval [0, 1] (in 'C:/Users/Studia/DOCUME~1/GitHub/PUBLIC~1/DATAAN~1/LAB2-I~1/code_2.stan', line 12, column 4 to column 25)
# 	Exception: bernoulli_lpmf: n[2] is 2, but must be in the interval [0, 1] (in 'C:/Users/Studia/DOCUME~1/GitHub/PUBLIC~1/DATAAN~1/LAB2-I~1/code_2.stan', line 12, column 4 to column 25)
# 	Exception: bernoulli_lpmf: n[2] is 2, but must be in the interval [0, 1] (in 'C:/Users/Studia/DOCUME~1/GitHub/PUBLIC~1/DATAAN~1/LAB2-I~1/code_2.stan', line 12, column 4 to column 25)
# 	Exception: bernoulli_lpmf: n[2] is 2, but must be in the interval [0, 1] (in 'C:/Users/Studia/DOCUME~1/GitHub/PUBLIC~1/DATAAN~1/LAB2-I~1/code_2.stan', line 12, column 4 to column 25)
# 	Exception: bernoulli_lpmf: n[2] is 2, but must be in the interval [0, 1] (in 'C:/Users/Studia/DOCUME~1/GitHub/PUBLIC~1/DATAAN~1/LAB2-I~1/code_2.stan', line 12, column 4 to column 25)
# 	Exception: bernoulli_lpmf: n[2] is 2, but must be in the interval [0, 1] (in 'C:/Users/Studia/DOCUME~1/GitHub/PUBLIC~1/DATAAN~1/LAB2-I~1/code_2.stan', line 12, column 4 to column 25)
# 	Exception: bernoulli_lpmf: n[2] is 2, but must be in the interval [0, 1] (in 'C:/Users/Studia/DOCUME~1/GitHub/PUBLIC~1/DATAAN~1/LAB2-I~1/code_2.stan', line 12, column 4 to column 25)
# 	Exception: bernoulli_lpmf: n[2] is 2, but must be in the interval [0, 1] (in 'C:/Users/Studia/DOCUME~1/GitHub/PUBLIC~1/DATAAN~1/LAB2-I~1/code_2.stan', line 12, column 4 to column 25)
# 	Exception: bernoulli_lpmf: n[2] is 2, but must be in the interval [0, 1] (in 'C:/Users/Studia/DOCUME~1/GitHub/PUBLIC~1/DATAAN~1/LAB2-I~1/code_2.stan', line 12, column 4 to column 25)
# 	Exception: bernoulli_lpmf: n[2] is 2, but must be in the interval [0, 1] (in 'C:/Users/Studia/DOCUME~1/GitHub/PUBLIC~1/DATAAN~1/LAB2-I~1/code_2.stan', line 12, column 4 to column 25)
# 	Exception: bernoulli_lpmf: n[2] is 2, but must be in the interval [0, 1] (in 'C:/Users/Studia/DOCUME~1/GitHub/PUBLIC~1/DATAAN~1/LAB2-I~1/code_2.stan', line 12, column 4 to column 25)
# 	Exception: bernoulli_lpmf: n[2] is 2, but must be in the interval [0, 1] (in 'C:/Users/Studia/DOCUME~1/GitHub/PUBLIC~1/DATAAN~1/LAB2-I~1/code_2.stan', line 12, column 4 to column 25)
# 	Exception: bernoulli_lpmf: n[2] is 2, but must be in the interval [0, 1] (in 'C:/Users/Studia/DOCUME~1/GitHub/PUBLIC~1/DATAAN~1/LAB2-I~1/code_2.stan', line 12, column 4 to column 25)
# 	Exception: bernoulli_lpmf: n[2] is 2, but must be in the interval [0, 1] (in 'C:/Users/Studia/DOCUME~1/GitHub/PUBLIC~1/DATAAN~1/LAB2-I~1/code_2.stan', line 12, column 4 to column 25)
# 	Exception: bernoulli_lpmf: n[2] is 2, but must be in the interval [0, 1] (in 'C:/Users/Studia/DOCUME~1/GitHub/PUBLIC~1/DATAAN~1/LAB2-I~1/code_2.stan', line 12, column 4 to column 25)
# 	Exception: bernoulli_lpmf: n[2] is 2, but must be in the interval [0, 1] (in 'C:/Users/Studia/DOCUME~1/GitHub/PUBLIC~1/DATAAN~1/LAB2-I~1/code_2.stan', line 12, column 4 to column 25)
# 	Exception: bernoulli_lpmf: n[2] is 2, but must be in the interval [0, 1] (in 'C:/Users/Studia/DOCUME~1/GitHub/PUBLIC~1/DATAAN~1/LAB2-I~1/code_2.stan', line 12, column 4 to column 25)
# 	Exception: bernoulli_lpmf: n[2] is 2, but must be in the interval [0, 1] (in 'C:/Users/Studia/DOCUME~1/GitHub/PUBLIC~1/DATAAN~1/LAB2-I~1/code_2.stan', line 12, column 4 to column 25)
# 	Exception: bernoulli_lpmf: n[2] is 2, but must be in the interval [0, 1] (in 'C:/Users/Studia/DOCUME~1/GitHub/PUBLIC~1/DATAAN~1/LAB2-I~1/code_2.stan', line 12, column 4 to column 25)
# 	Exception: bernoulli_lpmf: n[2] is 2, but must be in the interval [0, 1] (in 'C:/Users/Studia/DOCUME~1/GitHub/PUBLIC~1/DATAAN~1/LAB2-I~1/code_2.stan', line 12, column 4 to column 25)
# 	Exception: bernoulli_lpmf: n[2] is 2, but must be in the interval [0, 1] (in 'C:/Users/Studia/DOCUME~1/GitHub/PUBLIC~1/DATAAN~1/LAB2-I~1/code_2.stan', line 12, column 4 to column 25)
# 	Exception: bernoulli_lpmf: n[2] is 2, but must be in the interval [0, 1] (in 'C:/Users/Studia/DOCUME~1/GitHub/PUBLIC~1/DATAAN~1/LAB2-I~1/code_2.stan', line 12, column 4 to column 25)
# 	Exception: bernoulli_lpmf: n[2] is 2, but must be in the interval [0, 1] (in 'C:/Users/Studia/DOCUME~1/GitHub/PUBLIC~1/DATAAN~1/LAB2-I~1/code_2.stan', line 12, column 4 to column 25)
# 	Exception: bernoulli_lpmf: n[2] is 2, but must be in the interval [0, 1] (in 'C:/Users/Studia/DOCUME~1/GitHub/PUBLIC~1/DATAAN~1/LAB2-I~1/code_2.stan', line 12, column 4 to column 25)
# 	Exception: bernoulli_lpmf: n[2] is 2, but must be in the interval [0, 1] (in 'C:/Users/Studia/DOCUME~1/GitHub/PUBLIC~1/DATAAN~1/LAB2-I~1/code_2.stan', line 12, column 4 to column 25)
# 	Exception: bernoulli_lpmf: n[2] is 2, but must be in the interval [0, 1] (in 'C:/Users/Studia/DOCUME~1/GitHub/PUBLIC~1/DATAAN~1/LAB2-I~1/code_2.stan', line 12, column 4 to column 25)
# 	Exception: bernoulli_lpmf: n[2] is 2, but must be in the interval [0, 1] (in 'C:/Users/Studia/DOCUME~1/GitHub/PUBLIC~1/DATAAN~1/LAB2-I~1/code_2.stan', line 12, column 4 to column 25)
# 	Exception: bernoulli_lpmf: n[2] is 2, but must be in the interval [0, 1] (in 'C:/Users/Studia/DOCUME~1/GitHub/PUBLIC~1/DATAAN~1/LAB2-I~1/code_2.stan', line 12, column 4 to column 25)
# 	Exception: bernoulli_lpmf: n[2] is 2, but must be in the interval [0, 1] (in 'C:/Users/Studia/DOCUME~1/GitHub/PUBLIC~1/DATAAN~1/LAB2-I~1/code_2.stan', line 12, column 4 to column 25)
# 	Exception: bernoulli_lpmf: n[2] is 2, but must be in the interval [0, 1] (in 'C:/Users/Studia/DOCUME~1/GitHub/PUBLIC~1/DATAAN~1/LAB2-I~1/code_2.stan', line 12, column 4 to column 25)
# 	Exception: bernoulli_lpmf: n[2] is 2, but must be in the interval [0, 1] (in 'C:/Users/Studia/DOCUME~1/GitHub/PUBLIC~1/DATAAN~1/LAB2-I~1/code_2.stan', line 12, column 4 to column 25)
# 	Exception: bernoulli_lpmf: n[2] is 2, but must be in the interval [0, 1] (in 'C:/Users/Studia/DOCUME~1/GitHub/PUBLIC~1/DATAAN~1/LAB2-I~1/code_2.stan', line 12, column 4 to column 25)
# 	Exception: bernoulli_lpmf: n[2] is 2, but must be in the interval [0, 1] (in 'C:/Users/Studia/DOCUME~1/GitHub/PUBLIC~1/DATAAN~1/LAB2-I~1/code_2.stan', line 12, column 4 to column 25)
# 	Exception: bernoulli_lpmf: n[2] is 2, but must be in the interval [0, 1] (in 'C:/Users/Studia/DOCUME~1/GitHub/PUBLIC~1/DATAAN~1/LAB2-I~1/code_2.stan', line 12, column 4 to column 25)
# 	Exception: bernoulli_lpmf: n[2] is 2, but must be in the interval [0, 1] (in 'C:/Users/Studia/DOCUME~1/GitHub/PUBLIC~1/DATAAN~1/LAB2-I~1/code_2.stan', line 12, column 4 to column 25)
# 	Exception: bernoulli_lpmf: n[2] is 2, but must be in the interval [0, 1] (in 'C:/Users/Studia/DOCUME~1/GitHub/PUBLIC~1/DATAAN~1/LAB2-I~1/code_2.stan', line 12, column 4 to column 25)
# 	Exception: bernoulli_lpmf: n[2] is 2, but must be in the interval [0, 1] (in 'C:/Users/Studia/DOCUME~1/GitHub/PUBLIC~1/DATAAN~1/LAB2-I~1/code_2.stan', line 12, column 4 to column 25)
# 	Exception: bernoulli_lpmf: n[2] is 2, but must be in the interval [0, 1] (in 'C:/Users/Studia/DOCUME~1/GitHub/PUBLIC~1/DATAAN~1/LAB2-I~1/code_2.stan', line 12, column 4 to column 25)
# 	Exception: bernoulli_lpmf: n[2] is 2, but must be in the interval [0, 1] (in 'C:/Users/Studia/DOCUME~1/GitHub/PUBLIC~1/DATAAN~1/LAB2-I~1/code_2.stan', line 12, column 4 to column 25)
# 	Exception: bernoulli_lpmf: n[2] is 2, but must be in the interval [0, 1] (in 'C:/Users/Studia/DOCUME~1/GitHub/PUBLIC~1/DATAAN~1/LAB2-I~1/code_2.stan', line 12, column 4 to column 25)
# 	Exception: bernoulli_lpmf: n[2] is 2, but must be in the interval [0, 1] (in 'C:/Users/Studia/DOCUME~1/GitHub/PUBLIC~1/DATAAN~1/LAB2-I~1/code_2.stan', line 12, column 4 to column 25)
# 	Exception: bernoulli_lpmf: n[2] is 2, but must be in the interval [0, 1] (in 'C:/Users/Studia/DOCUME~1/GitHub/PUBLIC~1/DATAAN~1/LAB2-I~1/code_2.stan', line 12, column 4 to column 25)
# 	Exception: bernoulli_lpmf: n[2] is 2, but must be in the interval [0, 1] (in 'C:/Users/Studia/DOCUME~1/GitHub/PUBLIC~1/DATAAN~1/LAB2-I~1/code_2.stan', line 12, column 4 to column 25)
# 	Exception: bernoulli_lpmf: n[2] is 2, but must be in the interval [0, 1] (in 'C:/Users/Studia/DOCUME~1/GitHub/PUBLIC~1/DATAAN~1/LAB2-I~1/code_2.stan', line 12, column 4 to column 25)
# 	Exception: bernoulli_lpmf: n[2] is 2, but must be in the interval [0, 1] (in 'C:/Users/Studia/DOCUME~1/GitHub/PUBLIC~1/DATAAN~1/LAB2-I~1/code_2.stan', line 12, column 4 to column 25)
# 	Exception: bernoulli_lpmf: n[2] is 2, but must be in the interval [0, 1] (in 'C:/Users/Studia/DOCUME~1/GitHub/PUBLIC~1/DATAAN~1/LAB2-I~1/code_2.stan', line 12, column 4 to column 25)
# 	Exception: bernoulli_lpmf: n[2] is 2, but must be in the interval [0, 1] (in 'C:/Users/Studia/DOCUME~1/GitHub/PUBLIC~1/DATAAN~1/LAB2-I~1/code_2.stan', line 12, column 4 to column 25)
# 	Exception: bernoulli_lpmf: n[2] is 2, but must be in the interval [0, 1] (in 'C:/Users/Studia/DOCUME~1/GitHub/PUBLIC~1/DATAAN~1/LAB2-I~1/code_2.stan', line 12, column 4 to column 25)
# 	Exception: bernoulli_lpmf: n[2] is 2, but must be in the interval [0, 1] (in 'C:/Users/Studia/DOCUME~1/GitHub/PUBLIC~1/DATAAN~1/LAB2-I~1/code_2.stan', line 12, column 4 to column 25)
# 	Exception: bernoulli_lpmf: n[2] is 2, but must be in the interval [0, 1] (in 'C:/Users/Studia/DOCUME~1/GitHub/PUBLIC~1/DATAAN~1/LAB2-I~1/code_2.stan', line 12, column 4 to column 25)
# 	Exception: bernoulli_lpmf: n[2] is 2, but must be in the interval [0, 1] (in 'C:/Users/Studia/DOCUME~1/GitHub/PUBLIC~1/DATAAN~1/LAB2-I~1/code_2.stan', line 12, column 4 to column 25)
# 	Exception: bernoulli_lpmf: n[2] is 2, but must be in the interval [0, 1] (in 'C:/Users/Studia/DOCUME~1/GitHub/PUBLIC~1/DATAAN~1/LAB2-I~1/code_2.stan', line 12, column 4 to column 25)
# 	Exception: bernoulli_lpmf: n[2] is 2, but must be in the interval [0, 1] (in 'C:/Users/Studia/DOCUME~1/GitHub/PUBLIC~1/DATAAN~1/LAB2-I~1/code_2.stan', line 12, column 4 to column 25)
# 	Exception: bernoulli_lpmf: n[2] is 2, but must be in the interval [0, 1] (in 'C:/Users/Studia/DOCUME~1/GitHub/PUBLIC~1/DATAAN~1/LAB2-I~1/code_2.stan', line 12, column 4 to column 25)
# 	Exception: bernoulli_lpmf: n[2] is 2, but must be in the interval [0, 1] (in 'C:/Users/Studia/DOCUME~1/GitHub/PUBLIC~1/DATAAN~1/LAB2-I~1/code_2.stan', line 12, column 4 to column 25)
# 	Exception: bernoulli_lpmf: n[2] is 2, but must be in the interval [0, 1] (in 'C:/Users/Studia/DOCUME~1/GitHub/PUBLIC~1/DATAAN~1/LAB2-I~1/code_2.stan', line 12, column 4 to column 25)
# 	Exception: bernoulli_lpmf: n[2] is 2, but must be in the interval [0, 1] (in 'C:/Users/Studia/DOCUME~1/GitHub/PUBLIC~1/DATAAN~1/LAB2-I~1/code_2.stan', line 12, column 4 to column 25)
# 	Exception: bernoulli_lpmf: n[2] is 2, but must be in the interval [0, 1] (in 'C:/Users/Studia/DOCUME~1/GitHub/PUBLIC~1/DATAAN~1/LAB2-I~1/code_2.stan', line 12, column 4 to column 25)
# 	Exception: bernoulli_lpmf: n[2] is 2, but must be in the interval [0, 1] (in 'C:/Users/Studia/DOCUME~1/GitHub/PUBLIC~1/DATAAN~1/LAB2-I~1/code_2.stan', line 12, column 4 to column 25)
# 	Exception: bernoulli_lpmf: n[2] is 2, but must be in the interval [0, 1] (in 'C:/Users/Studia/DOCUME~1/GitHub/PUBLIC~1/DATAAN~1/LAB2-I~1/code_2.stan', line 12, column 4 to column 25)
# 	Exception: bernoulli_lpmf: n[2] is 2, but must be in the interval [0, 1] (in 'C:/Users/Studia/DOCUME~1/GitHub/PUBLIC~1/DATAAN~1/LAB2-I~1/code_2.stan', line 12, column 4 to column 25)
# 	Exception: bernoulli_lpmf: n[2] is 2, but must be in the interval [0, 1] (in 'C:/Users/Studia/DOCUME~1/GitHub/PUBLIC~1/DATAAN~1/LAB2-I~1/code_2.stan', line 12, column 4 to column 25)
# 	Exception: bernoulli_lpmf: n[2] is 2, but must be in the interval [0, 1] (in 'C:/Users/Studia/DOCUME~1/GitHub/PUBLIC~1/DATAAN~1/LAB2-I~1/code_2.stan', line 12, column 4 to column 25)
# 	Exception: bernoulli_lpmf: n[2] is 2, but must be in the interval [0, 1] (in 'C:/Users/Studia/DOCUME~1/GitHub/PUBLIC~1/DATAAN~1/LAB2-I~1/code_2.stan', line 12, column 4 to column 25)
# 	Exception: bernoulli_lpmf: n[2] is 2, but must be in the interval [0, 1] (in 'C:/Users/Studia/DOCUME~1/GitHub/PUBLIC~1/DATAAN~1/LAB2-I~1/code_2.stan', line 12, column 4 to column 25)
# 	Exception: bernoulli_lpmf: n[2] is 2, but must be in the interval [0, 1] (in 'C:/Users/Studia/DOCUME~1/GitHub/PUBLIC~1/DATAAN~1/LAB2-I~1/code_2.stan', line 12, column 4 to column 25)
# 	Exception: bernoulli_lpmf: n[2] is 2, but must be in the interval [0, 1] (in 'C:/Users/Studia/DOCUME~1/GitHub/PUBLIC~1/DATAAN~1/LAB2-I~1/code_2.stan', line 12, column 4 to column 25)
# 	Exception: bernoulli_lpmf: n[2] is 2, but must be in the interval [0, 1] (in 'C:/Users/Studia/DOCUME~1/GitHub/PUBLIC~1/DATAAN~1/LAB2-I~1/code_2.stan', line 12, column 4 to column 25)
# 	Exception: bernoulli_lpmf: n[2] is 2, but must be in the interval [0, 1] (in 'C:/Users/Studia/DOCUME~1/GitHub/PUBLIC~1/DATAAN~1/LAB2-I~1/code_2.stan', line 12, column 4 to column 25)
# 	Exception: bernoulli_lpmf: n[2] is 2, but must be in the interval [0, 1] (in 'C:/Users/Studia/DOCUME~1/GitHub/PUBLIC~1/DATAAN~1/LAB2-I~1/code_2.stan', line 12, column 4 to column 25)
# 	Exception: bernoulli_lpmf: n[2] is 2, but must be in the interval [0, 1] (in 'C:/Users/Studia/DOCUME~1/GitHub/PUBLIC~1/DATAAN~1/LAB2-I~1/code_2.stan', line 12, column 4 to column 25)
# 	Exception: bernoulli_lpmf: n[2] is 2, but must be in the interval [0, 1] (in 'C:/Users/Studia/DOCUME~1/GitHub/PUBLIC~1/DATAAN~1/LAB2-I~1/code_2.stan', line 12, column 4 to column 25)
# 	Exception: bernoulli_lpmf: n[2] is 2, but must be in the interval [0, 1] (in 'C:/Users/Studia/DOCUME~1/GitHub/PUBLIC~1/DATAAN~1/LAB2-I~1/code_2.stan', line 12, column 4 to column 25)
# 	Exception: bernoulli_lpmf: n[2] is 2, but must be in the interval [0, 1] (in 'C:/Users/Studia/DOCUME~1/GitHub/PUBLIC~1/DATAAN~1/LAB2-I~1/code_2.stan', line 12, column 4 to column 25)
# 	Exception: bernoulli_lpmf: n[2] is 2, but must be in the interval [0, 1] (in 'C:/Users/Studia/DOCUME~1/GitHub/PUBLIC~1/DATAAN~1/LAB2-I~1/code_2.stan', line 12, column 4 to column 25)
# 	Exception: bernoulli_lpmf: n[2] is 2, but must be in the interval [0, 1] (in 'C:/Users/Studia/DOCUME~1/GitHub/PUBLIC~1/DATAAN~1/LAB2-I~1/code_2.stan', line 12, column 4 to column 25)
# 	Exception: bernoulli_lpmf: n[2] is 2, but must be in the interval [0, 1] (in 'C:/Users/Studia/DOCUME~1/GitHub/PUBLIC~1/DATAAN~1/LAB2-I~1/code_2.stan', line 12, column 4 to column 25)
# 	Exception: bernoulli_lpmf: n[2] is 2, but must be in the interval [0, 1] (in 'C:/Users/Studia/DOCUME~1/GitHub/PUBLIC~1/DATAAN~1/LAB2-I~1/code_2.stan', line 12, column 4 to column 25)
# 	Exception: bernoulli_lpmf: n[2] is 2, but must be in the interval [0, 1] (in 'C:/Users/Studia/DOCUME~1/GitHub/PUBLIC~1/DATAAN~1/LAB2-I~1/code_2.stan', line 12, column 4 to column 25)

# %%
bern2 = CmdStanModel(stan_file='code_3.stan')
samp_bern2 = bern2.sample(data={'N':2, 'y':[0,2]})
# Out:
# INFO:cmdstanpy:compiling stan program, exe file: C:/Users/Studia/DOCUME~1/GitHub/PUBLIC~1/DATAAN~1/LAB2-I~1/code_3.exe
# INFO:cmdstanpy:compiler options: stanc_options=None, cpp_options=None
# INFO:cmdstanpy:compiled model file: C:/Users/Studia/DOCUME~1/GitHub/PUBLIC~1/DATAAN~1/LAB2-I~1/code_3.exe
# INFO:cmdstanpy:start chain 1
# INFO:cmdstanpy:start chain 2
# INFO:cmdstanpy:finish chain 1
# INFO:cmdstanpy:start chain 3
# INFO:cmdstanpy:finish chain 2
# INFO:cmdstanpy:start chain 4
# INFO:cmdstanpy:finish chain 3
# INFO:cmdstanpy:finish chain 4
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-16-da8a2541d9d2> in <module>
#       1 bern2 = CmdStanModel(stan_file='code_3.stan')
# ----> 2 samp_bern2 = bern2.sample(data={'N':2, 'y':[0,2]})
#
# ~\anaconda3\lib\site-packages\cmdstanpy\model.py in sample(self, data, chains, parallel_chains, threads_per_chain, seed, chain_ids, inits, iter_warmup, iter_sampling, save_warmup, thin, max_treedepth, metric, step_size, adapt_engaged, adapt_delta, adapt_init_phase, adapt_metric_window, adapt_step_size, fixed_param, output_dir, sig_figs, save_diagnostics, show_progress, validate_csv)
#     787             if not runset._check_retcodes():
#     788                 msg = 'Error during sampling.\n{}'.format(runset.get_err_msgs())
# --> 789                 raise RuntimeError(msg)
#     790
#     791             mcmc = CmdStanMCMC(runset, validate_csv, logger=self._logger)
#
# RuntimeError: Error during sampling.
# RunSet: chains=4
#  cmd:
# 	['C:/Users/Studia/DOCUME~1/GitHub/PUBLIC~1/DATAAN~1/LAB2-I~1/code_3.exe', 'id=1', 'random', 'seed=14642', 'data', 'file=C:\\Users\\Studia\\AppData\\Local\\Temp\\tmph4ysj6l4\\fv9jprrp.json', 'output', 'file=C:\\Users\\Studia\\AppData\\Local\\Temp\\tmph4ysj6l4\\code_3-202103241209-1-auwc49z8.csv', 'method=sample', 'algorithm=hmc', 'adapt', 'engaged=1']
#  retcodes=[70, 70, 70, 70]
#  csv_files:
# 	C:\Users\Studia\AppData\Local\Temp\tmph4ysj6l4\code_3-202103241209-1-auwc49z8.csv
# 	C:\Users\Studia\AppData\Local\Temp\tmph4ysj6l4\code_3-202103241209-2-_v7oxxfm.csv
# 	C:\Users\Studia\AppData\Local\Temp\tmph4ysj6l4\code_3-202103241209-3-gkeooa63.csv
# 	C:\Users\Studia\AppData\Local\Temp\tmph4ysj6l4\code_3-202103241209-4-64f733tg.csv
#  console_msgs:
# 	C:\Users\Studia\AppData\Local\Temp\tmph4ysj6l4\code_3-202103241209-1-auwc49z8-stdout.txt
# 	C:\Users\Studia\AppData\Local\Temp\tmph4ysj6l4\code_3-202103241209-2-_v7oxxfm-stdout.txt
# 	C:\Users\Studia\AppData\Local\Temp\tmph4ysj6l4\code_3-202103241209-3-gkeooa63-stdout.txt
# 	C:\Users\Studia\AppData\Local\Temp\tmph4ysj6l4\code_3-202103241209-4-64f733tg-stdout.txt
# chain_id 1:
# 	Exception: code_3_model_namespace::code_3_model: y[sym1__] is 2, but must be less than or equal to 1 (in 'C:/Users/Studia/DOCUME~1/GitHub/PUBLIC~1/DATAAN~1/LAB2-I~1/code_3.stan', line 4, column 4 to column 30)
#
# chain_id 2:
# 	Exception: code_3_model_namespace::code_3_model: y[sym1__] is 2, but must be less than or equal to 1 (in 'C:/Users/Studia/DOCUME~1/GitHub/PUBLIC~1/DATAAN~1/LAB2-I~1/code_3.stan', line 4, column 4 to column 30)
#
# chain_id 3:
# 	Exception: code_3_model_namespace::code_3_model: y[sym1__] is 2, but must be less than or equal to 1 (in 'C:/Users/Studia/DOCUME~1/GitHub/PUBLIC~1/DATAAN~1/LAB2-I~1/code_3.stan', line 4, column 4 to column 30)
#
# chain_id 4:
# 	Exception: code_3_model_namespace::code_3_model: y[sym1__] is 2, but must be less than or equal to 1 (in 'C:/Users/Studia/DOCUME~1/GitHub/PUBLIC~1/DATAAN~1/LAB2-I~1/code_3.stan', line 4, column 4 to column 30)

# %%
#

# %% [markdown]
# ## Excercise 3 - Constraints on parameters

# %% [markdown]
# ### Unconstrained parameters

# %%
model_gm1 = CmdStanModel(stan_file='code_4.stan')
out_gamma1 = model_gm1.sample(output_dir='samples',iter_sampling=6000,iter_warmup=1000, seed=4838282)
out_gamma1.diagnose()
# Out:
# INFO:cmdstanpy:compiling stan program, exe file: C:/Users/Studia/DOCUME~1/GitHub/PUBLIC~1/DATAAN~1/LAB2-I~1/code_4.exe
# INFO:cmdstanpy:compiler options: stanc_options=None, cpp_options=None
# INFO:cmdstanpy:compiled model file: C:/Users/Studia/DOCUME~1/GitHub/PUBLIC~1/DATAAN~1/LAB2-I~1/code_4.exe
# INFO:cmdstanpy:created output directory: C:\Users\Studia\Documents\GitHub\public_lectures\Data Analytics\Lab 2 - Intro to stan\samples
# INFO:cmdstanpy:start chain 1
# INFO:cmdstanpy:start chain 2
# INFO:cmdstanpy:finish chain 1
# INFO:cmdstanpy:start chain 3
# INFO:cmdstanpy:finish chain 2
# INFO:cmdstanpy:start chain 4
# INFO:cmdstanpy:finish chain 4
# INFO:cmdstanpy:finish chain 3
# INFO:cmdstanpy:Processing csv files: C:\Users\Studia\Documents\GitHub\public_lectures\Data Analytics\Lab 2 - Intro to stan\samples\code_4-202103241211-1.csv, C:\Users\Studia\Documents\GitHub\public_lectures\Data Analytics\Lab 2 - Intro to stan\samples\code_4-202103241211-2.csv, C:\Users\Studia\Documents\GitHub\public_lectures\Data Analytics\Lab 2 - Intro to stan\samples\code_4-202103241211-3.csv, C:\Users\Studia\Documents\GitHub\public_lectures\Data Analytics\Lab 2 - Intro to stan\samples\code_4-202103241211-4.csv
#
# Checking sampler transitions treedepth.
# Treedepth satisfactory for all transitions.
#
# Checking sampler transitions for divergences.
# 8638 of 24000 (36%) transitions ended with a divergence.
# These divergent transitions indicate that HMC is not fully able to explore the posterior distribution.
# Try increasing adapt delta closer to 1.
# If this doesn't remove all divergences, try to reparameterize the model.
#
# Checking E-BFMI - sampler transitions HMC potential energy.
# E-BFMI satisfactory for all transitions.
#
# Effective sample size satisfactory.
#
# Split R-hat values satisfactory all parameters.
#
# Processing complete.
# "Processing csv files: C:\\Users\\Studia\\Documents\\GitHub\\public_lectures\\Data Analytics\\Lab 2 - Intro to stan\\samples\\code_4-202103241211-1.csv, C:\\Users\\Studia\\Documents\\GitHub\\public_lectures\\Data Analytics\\Lab 2 - Intro to stan\\samples\\code_4-202103241211-2.csv, C:\\Users\\Studia\\Documents\\GitHub\\public_lectures\\Data Analytics\\Lab 2 - Intro to stan\\samples\\code_4-202103241211-3.csv, C:\\Users\\Studia\\Documents\\GitHub\\public_lectures\\Data Analytics\\Lab 2 - Intro to stan\\samples\\code_4-202103241211-4.csv\r\n\r\nChecking sampler transitions treedepth.\r\nTreedepth satisfactory for all transitions.\r\n\r\nChecking sampler transitions for divergences.\r\n8638 of 24000 (36%) transitions ended with a divergence.\r\nThese divergent transitions indicate that HMC is not fully able to explore the posterior distribution.\r\nTry increasing adapt delta closer to 1.\r\nIf this doesn't remove all divergences, try to reparameterize the model.\r\n\r\nChecking E-BFMI - sampler transitions HMC potential energy.\r\nE-BFMI satisfactory for all transitions.\r\n\r\nEffective sample size satisfactory.\r\n\r\nSplit R-hat values satisfactory all parameters.\r\n\r\nProcessing complete."

# %%
N=500
xs = np.linspace(0,8,N)
pdfs = stats.gamma.pdf(xs, 1.25, scale = 1 / 1.25) 

plt.plot(xs, pdfs, linewidth=2)

## add histogram of theta samples with 160 bins

plt.gca().set_xlabel("theta")
plt.gca().set_ylabel("Probability Density Function")
plt.show()

# %% [markdown]
# ### Constrained parameter

# %%
model_gm2 = CmdStanModel(stan_file='code_5.stan')
out_gamma2 = model_gm2.sample(output_dir='samples',iter_sampling=6000,iter_warmup=1000, seed=4838282)
out_gamma2.diagnose()
# Out:
# INFO:cmdstanpy:compiling stan program, exe file: C:/Users/Studia/DOCUME~1/GitHub/PUBLIC~1/DATAAN~1/LAB2-I~1/code_5.exe
# INFO:cmdstanpy:compiler options: stanc_options=None, cpp_options=None
# INFO:cmdstanpy:compiled model file: C:/Users/Studia/DOCUME~1/GitHub/PUBLIC~1/DATAAN~1/LAB2-I~1/code_5.exe
# INFO:cmdstanpy:start chain 1
# INFO:cmdstanpy:start chain 2
# INFO:cmdstanpy:finish chain 2
# INFO:cmdstanpy:start chain 3
# INFO:cmdstanpy:finish chain 1
# INFO:cmdstanpy:start chain 4
# INFO:cmdstanpy:finish chain 3
# INFO:cmdstanpy:finish chain 4
# INFO:cmdstanpy:Processing csv files: C:\Users\Studia\Documents\GitHub\public_lectures\Data Analytics\Lab 2 - Intro to stan\samples\code_5-202103241212-1.csv, C:\Users\Studia\Documents\GitHub\public_lectures\Data Analytics\Lab 2 - Intro to stan\samples\code_5-202103241212-2.csv, C:\Users\Studia\Documents\GitHub\public_lectures\Data Analytics\Lab 2 - Intro to stan\samples\code_5-202103241212-3.csv, C:\Users\Studia\Documents\GitHub\public_lectures\Data Analytics\Lab 2 - Intro to stan\samples\code_5-202103241212-4.csv
#
# Checking sampler transitions treedepth.
# Treedepth satisfactory for all transitions.
#
# Checking sampler transitions for divergences.
# 1 of 24000 (0.0042%) transitions ended with a divergence.
# These divergent transitions indicate that HMC is not fully able to explore the posterior distribution.
# Try increasing adapt delta closer to 1.
# If this doesn't remove all divergences, try to reparameterize the model.
#
# Checking E-BFMI - sampler transitions HMC potential energy.
# E-BFMI satisfactory for all transitions.
#
# Effective sample size satisfactory.
#
# Split R-hat values satisfactory all parameters.
#
# Processing complete.
# "Processing csv files: C:\\Users\\Studia\\Documents\\GitHub\\public_lectures\\Data Analytics\\Lab 2 - Intro to stan\\samples\\code_5-202103241212-1.csv, C:\\Users\\Studia\\Documents\\GitHub\\public_lectures\\Data Analytics\\Lab 2 - Intro to stan\\samples\\code_5-202103241212-2.csv, C:\\Users\\Studia\\Documents\\GitHub\\public_lectures\\Data Analytics\\Lab 2 - Intro to stan\\samples\\code_5-202103241212-3.csv, C:\\Users\\Studia\\Documents\\GitHub\\public_lectures\\Data Analytics\\Lab 2 - Intro to stan\\samples\\code_5-202103241212-4.csv\r\n\r\nChecking sampler transitions treedepth.\r\nTreedepth satisfactory for all transitions.\r\n\r\nChecking sampler transitions for divergences.\r\n1 of 24000 (0.0042%) transitions ended with a divergence.\r\nThese divergent transitions indicate that HMC is not fully able to explore the posterior distribution.\r\nTry increasing adapt delta closer to 1.\r\nIf this doesn't remove all divergences, try to reparameterize the model.\r\n\r\nChecking E-BFMI - sampler transitions HMC potential energy.\r\nE-BFMI satisfactory for all transitions.\r\n\r\nEffective sample size satisfactory.\r\n\r\nSplit R-hat values satisfactory all parameters.\r\n\r\nProcessing complete."

# %%
N=500
xs = np.linspace(0,8,N)
pdfs = stats.gamma.pdf(xs, 1.25, scale = 1 / 1.25) 

plt.plot(xs, pdfs, linewidth=2)

## add histogram of theta samples from the second model with 160 bins

plt.gca().set_xlabel("theta")
plt.gca().set_ylabel("Probability Density Function")
plt.show()

fig, ax = plt.subplot(1,1)
ax.hist(df['theta'], bins=160,density=True)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-30-e58dbaf4f6d7> in <module>
#      11 plt.show()
#      12
# ---> 13 fig, ax = plt.subplot(1,1)
#      14 ax.hist(df['theta'], bins=160,density=True)
#      15 plt.show()
#
# ~\anaconda3\lib\site-packages\matplotlib\pyplot.py in subplot(*args, **kwargs)
#    1140
#    1141     fig = gcf()
# -> 1142     ax = fig.add_subplot(*args, **kwargs)
#    1143     bbox = ax.bbox
#    1144     axes_to_delete = []
#
# ~\anaconda3\lib\site-packages\matplotlib\figure.py in add_subplot(self, *args, **kwargs)
#    1400                     # more similar to add_axes.
#    1401                     self._axstack.remove(ax)
# -> 1402             ax = subplot_class_factory(projection_class)(self, *args, **kwargs)
#    1403
#    1404         return self._add_axes_internal(key, ax)
#
# ~\anaconda3\lib\site-packages\matplotlib\axes\_subplots.py in __init__(self, fig, *args, **kwargs)
#      37
#      38         self.figure = fig
# ---> 39         self._subplotspec = SubplotSpec._from_subplot_args(fig, args)
#      40         self.update_params()
#      41         # _axes_class is set in the subplot_class_factory
#
# ~\anaconda3\lib\site-packages\matplotlib\gridspec.py in _from_subplot_args(figure, args)
#     691                 return gs[num - 1]   # -1 due to MATLAB indexing.
#     692         else:
# --> 693             raise TypeError(f"subplot() takes 1 or 3 positional arguments but "
#     694                             f"{len(args)} were given")
#     695
#
# TypeError: subplot() takes 1 or 3 positional arguments but 2 were given

# %% [markdown]
# ## Excercise 4 -  Selection of parameters using equation solving

# %%
model_tune = CmdStanModel(stan_file='code_6.stan')

#F = # number of letters in the first name
#L = # number of letters in the last name
y0 = 3

data={'y_guess':[y0],
        'theta':[(F+L)/2]}
tunes = model_tune.sample(data=data, fixed_param=True, iter_sampling=1, iter_warmup=0, chains = 1)
# Out:
# INFO:cmdstanpy:compiling stan program, exe file: C:/Users/Studia/DOCUME~1/GitHub/PUBLIC~1/DATAAN~1/LAB2-I~1/code_6.exe
# INFO:cmdstanpy:compiler options: stanc_options=None, cpp_options=None
# INFO:cmdstanpy:compiled model file: C:/Users/Studia/DOCUME~1/GitHub/PUBLIC~1/DATAAN~1/LAB2-I~1/code_6.exe
# INFO:cmdstanpy:start chain 1
# INFO:cmdstanpy:finish chain 1

# %%
samples.draws_pd()
# Out:
# WARNING:cmdstanpy:method "draws_pd" is slated for removal.
#      lp__  accept_stat__     lambda  y_sim[1]  y_sim[2]  y_sim[3]  y_sim[4]  \
# 0     0.0            0.0  191.56200     196.0     205.0     200.0     170.0
# 1     0.0            0.0   53.35080      55.0      52.0      52.0      56.0
# 2     0.0            0.0  120.45900     123.0     140.0     108.0     150.0
# 3     0.0            0.0  162.01100     162.0     182.0     183.0     168.0
# 4     0.0            0.0  224.81800     233.0     204.0     199.0     223.0
# ..    ...            ...        ...       ...       ...       ...       ...
# 995   0.0            0.0  195.91200     187.0     210.0     212.0     216.0
# 996   0.0            0.0  259.30300     264.0     272.0     270.0     253.0
# 997   0.0            0.0   85.05940      86.0      85.0      76.0      82.0
# 998   0.0            0.0   82.52890      81.0      92.0      83.0      83.0
# 999   0.0            0.0    7.05839       6.0       8.0       7.0       8.0
#
#      y_sim[5]  y_sim[6]
# 0       205.0     174.0
# 1        54.0      47.0
# 2       100.0     137.0
# 3       172.0     158.0
# 4       221.0     215.0
# ..        ...       ...
# 995     169.0     211.0
# 996     275.0     244.0
# 997      83.0      79.0
# 998      79.0      80.0
# 999       2.0       6.0
#
# [1000 rows x 9 columns]
